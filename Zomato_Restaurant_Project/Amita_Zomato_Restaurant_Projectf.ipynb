# %% [markdown]
# ## Zomato Restaurant project

# %% [markdown]
# #### By: Amita Saini Internship batch 34

# %% [markdown]
# #### Project Description
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %% [markdown]
# #### Data Storage:
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
# • Country code
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
# • Restaurant Id: Unique id of every restaurant across various cities of the world
# • Restaurant Name: Name of the restaurant
# • Country Code: Country in which restaurant is located
# • City: City in which restaurant is located
# • Address: Address of the restaurant
# • Locality: Location in the city
# • Locality Verbose: Detailed description of the locality
# • Longitude: Longitude coordinate of the restaurant&#39;s location
# • Latitude: Latitude coordinate of the restaurant&#39;s location
# • Cuisines: Cuisines offered by the restaurant
# • Average Cost for two: Cost for two people in different currencies
# • Currency: Currency of the country
# • Has Table booking: yes/no
# • Has Online delivery: yes/ no
# • Is delivering: yes/ no
# • Switch to order menu: yes/no
# • Price range: range of price of food
# • Aggregate Rating: Average rating out of 5
# • Rating color: depending upon the average rating color
# • Rating text: text on the basis of rating of rating
# • Votes: Number of ratings casted by people
#
# #### Problem statement : In this dataset predict 2 things –
# 1) Average Cost for two
# 2) Price range
#
#
# #### Hint :
# Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets
#
#
# #### Dataset Link-
# •	https://github.com/dsrscientist/dataset4/blob/main/Country-Code.xlsx
# •	https://github.com/dsrscientist/dataset4/blob/main/zomato.csv

# %%
#### Let us Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# #### Let us Import dataset file

# %%
data = pd.read_csv("zomato.csv",encoding="latin-1")

# %% [markdown]
# #### Let us find Shape of dataset

# %%
data.shape
# Out:
# (9551, 21)

# %% [markdown]
# #### Let us find head of the dataset

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# #### Let us find Data Type

# %%
data.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# #### Let us know Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# #### Let us find Maximum votes

# %%
data.Votes.max()
# Out:
# 10934

# %% [markdown]
# #### Let us Check for null values

# %%
data.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %% [markdown]
# #### Let us Find columnwise null values

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ###### Observations:
# Column Cuisine has null values and total number of null values  is 9.

# %% [markdown]
# #### Lets check data shape again

# %%
data.shape
# Out:
# (9551, 21)

# %% [markdown]
# 9551 rows and 19 columns

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ####  There are null values in the cuisine column but dropping the rows having null cuisine values may affect the analysis later on. It is very less in number also. so let us fill the missing value with NaN or  leave it as it is.

# %%
## first lets check type of values in cuisine column

print(data.Cuisines.dtypes)
# Out:
# object

# %% [markdown]
# #### Oservations:
# As data type is Object, let us replace the missing values with NaN

# %%
## Let us fill the missing values in Cuisines column with NaN

data['Cuisines'] = data['Cuisines'].fillna('NaN')

# %% [markdown]
# #### Let us Check missing value in Cuisines column again

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# #### Oservations:
# No null values in any columns

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# #### Let us import next data set of country code

# %%
data1 = pd.read_excel("Country_Code.xlsx")
data1.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %% [markdown]
# #### Let us know shape of this data set

# %%
data1.shape
# Out:
# (15, 2)

# %% [markdown]
# 15 rows and 2 columns

# %%
data1.describe()
# Out:
#        Country Code
# count     15.000000
# mean     137.933333
# std       80.009345
# min        1.000000
# 25%       65.500000
# 50%      166.000000
# 75%      199.500000
# max      216.000000

# %% [markdown]
# #### Observations:
# data1.describe has calculated mean, median etc for Country_Code,

# %%
data1.dtypes
# Out:
# Country Code     int64
# Country         object
# dtype: object

# %% [markdown]
# #### Let us check null values in the Country_Code dataset

# %%
data1.isnull()
# Out:
#     Country Code  Country
# 0          False    False
# 1          False    False
# 2          False    False
# 3          False    False
# 4          False    False
# 5          False    False
# 6          False    False
# 7          False    False
# 8          False    False
# 9          False    False
# 10         False    False
# 11         False    False
# 12         False    False
# 13         False    False
# 14         False    False

# %% [markdown]
# #### Oservations:
# There are no null values

# %% [markdown]
# #### Let us know Country_Code data set further

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 368.0+ bytes

# %% [markdown]
# ####  Let us merge zomato dataset to Country_Code dataset to understand which country code belongs to which country and further  analysis.

# %%
final_data=pd.merge(data,data1,on='Country Code',how='left')
final_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_data.shape
# Out:
# (9551, 22)

# %% [markdown]
# #### Observations:
# 1. Both data sets are now merged.
# 2. There are 9551 entries which are the total number of restaurants listed on Zomato world wide and corresponding that there are 17 columns which provide  a brief description about a particular restaurant.

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# Let us find out which country has the highest number of restaurants listed on Zomato

# %%
final_data.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# #### Observations:
# India has the highest number of restaurants.

# %%
final_data.Country
# Out:
# 0       Phillipines
# 1       Phillipines
# 2       Phillipines
# 3       Phillipines
# 4       Phillipines
#            ...
# 9546         Turkey
# 9547         Turkey
# 9548         Turkey
# 9549         Turkey
# 9550         Turkey
# Name: Country, Length: 9551, dtype: object

# %%
country_name = final_data.Country.value_counts().index
country_name
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
country_value = final_data.Country.value_counts().values
country_value
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Let us understand the rating distribution of the restaurants.

# %%
ratings = data.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# #### Observations:
# It shows how the ratings are ditributed, the color associated with each rating and also the number of the reviews each rating has received.

# %% [markdown]
# Rating 0 - White - Not rated
#
# Rating 1.8 to 2.4 - Red - Poor
#
# Rating 2.5 to 3.4 - Orange - Average
#
# Rating 3.5 to 3.9 - Yellow - Good
#
# Rating 4.0 to 4.4 - Green - Very Good
#
# Rating 4.5 to 4.9 - Dark Green - Excellent

# %% [markdown]
# #### Let us see which country has the highest number of unrated restaurants.

# %%
No_rating = final_data[final_data['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
No_rating
# Out:
#           Country  Rating Count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %% [markdown]
# #### Observations:
# 1. India has come out on top.
#
# 2. This Indians prefering online food ordering and have it at home.

# %% [markdown]
# #### Bar chart  visualisation of the rating distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating Count',data=ratings)
plt.show()

# %% [markdown]
# #### Observations:
# The highest number of ratings recieved is in range of 3.0 to 3.8 due to the number of restaurants which have high rating is low in number. India has the most number of restaurants and many restaurants fall into the bucket of 3 to 4 rating range.

# %% [markdown]
# #### Let us understand currency for each country

# %%
country_currency = final_data[['Country','Currency']].groupby(['Country','Currency']).size().reset_index(name='count').drop('count', axis=1, inplace=False)
country_currency
# Out:
#            Country                Currency
# 0        Australia               Dollar($)
# 1           Brazil      Brazilian Real(R$)
# 2           Canada               Dollar($)
# 3            India      Indian Rupees(Rs.)
# 4        Indonesia  Indonesian Rupiah(IDR)
# 5      New Zealand           NewZealand($)
# 6      Phillipines        Botswana Pula(P)
# 7            Qatar         Qatari Rial(QR)
# 8        Singapore               Dollar($)
# 9     South Africa                 Rand(R)
# 10       Sri Lanka   Sri Lankan Rupee(LKR)
# 11          Turkey        Turkish Lira(TL)
# 12             UAE      Emirati Diram(AED)
# 13  United Kingdom              Pounds(£)
# 14   United States               Dollar($)

# %% [markdown]
# #### Let us find out country wise online delivery restaurants

# %%
country_online_delivery = final_data[["Has Online delivery", 'Country']].groupby(["Has Online delivery", 'Country']).size().reset_index(name='Count')
country_online_delivery
# Out:
#    Has Online delivery         Country  Count
# 0                   No       Australia     24
# 1                   No          Brazil     60
# 2                   No          Canada      4
# 3                   No           India   6229
# 4                   No       Indonesia     21
# 5                   No     New Zealand     40
# 6                   No     Phillipines     22
# 7                   No           Qatar     20
# 8                   No       Singapore     20
# 9                   No    South Africa     60
# 10                  No       Sri Lanka     20
# 11                  No          Turkey     34
# 12                  No             UAE     32
# 13                  No  United Kingdom     80
# 14                  No   United States    434
# 15                 Yes           India   2423
# 16                 Yes             UAE     28

# %% [markdown]
# #### Observations:
# 1. Only India and UAE have online delivery, India tops the list of having most number of restaurants having online deliveries.

# %% [markdown]
# #### Let us gather information on cuisines.

# %% [markdown]
# Let us extarct the top 25 restaurants.

# %%
final_data.loc[final_data['Rating text'].isin(['Excellent'])].Cuisines.value_counts().sort_values(ascending=False).reset_index().head()
# Out:
#           index  Cuisines
# 0          Cafe         8
# 1  North Indian         7
# 2       Italian         7
# 3        Indian         5
# 4       Seafood         5

# %% [markdown]
# Let us get the resturants having 'Excellent' and 'Very Good' rating

# %%
good_cuisine = final_data.loc[final_data['Rating text'].isin(['Excellent'])]

good_cuisine = good_cuisine.Cuisines.value_counts().reset_index().head(25)

## Extracing all the cuisens in a single list
cuisines = []

for cuisine in good_cuisine['index']: 
  cuisines.append(cuisine)

# cuisien = '[%s]'%', '.join(map(str, cuisien))
cuisines
# Out:
# ['Cafe',
#  'Italian',
#  'North Indian',
#  'Indian',
#  'Seafood',
#  'Ice Cream',
#  'Desserts',
#  'Asian',
#  'North Indian, Mughlai',
#  'Sunda, Indonesian',
#  'Indian, North Indian',
#  'Modern Indian',
#  'Thai',
#  'Desserts, Ice Cream',
#  'European, Mediterranean, North Indian',
#  'Fast Food',
#  'North Indian, Chinese',
#  'Mexican, American, Tex-Mex, Burger',
#  'Japanese',
#  'American',
#  'Italian, Pizza',
#  'Brazilian, Bar Food',
#  'Japanese, Sushi',
#  'Burger',
#  'Bakery, Desserts']

# %%
sns.barplot(y = 'index', x = 'Cuisines', data = good_cuisine)
plt.show()

# %% [markdown]
# #### Observations:
# 1. Graph shows the number of cuisines.
# 2. Cafes serve the most number of cuisines and Bakery, Deserts serving the the least number of cuisines.

# %%
costly_zomato = final_data.nlargest(25, 'Average Cost for two')
costly_zomato
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 9283        7402935                                      Skye            94
# 9284        7410290                  Satoo - Hotel Shangri-La            94
# 9287        7420899                                Sushi Masa            94
# 9289        7421967                            3 Wise Monkeys            94
# 9294        7422489               Avec Moi Restaurant and Bar            94
# 9288       18352452                Lucky Cat Coffee & Kitchen            94
# 9295       18386856                                   Onokabe            94
# 9278        7423482                                Lemongrass            94
# 9285       18391256                                     MONKS            94
# 9279        7422633                          Talaga Sampireun            94
# 9281       18425821                                      OJJU            94
# ...

# %%
costly_zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# #### Top 25 costly Resturants' Locations

# %%
final_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_data[(final_data['Average Cost for two']<10000) & (final_data['Aggregate rating']!=0)].plot.scatter(x = 'Average Cost for two', y = 'Aggregate rating', figsize=(15,7), title="The dependence of the rating on the price for two")
plt.show()

# %% [markdown]
# #### Observations:
# This graph shows how the Price range is distributed around the aggregrate rating. The maximum number of restaurants falls in the 0 - 1000 price range and 2.5 to 4.0 rating.

# %% [markdown]
# #### Scatter Plot of Price Range vs Aggregate Rating

# %%
scatter_price_rating = final_data.plot.scatter('Aggregate rating','Votes',figsize = (7,5))
plt.title("Relationship betweeen Votes and Aggregate rating")
plt.show()

# %% [markdown]
# #### Observations:
# This graph shows the relationship between the number of votes and Aggregrate Rating.
# The maximum number of ratings lie between 3.5 to 4.8 whereas the frequency of votes which they have received are in the range 0-2000

# %% [markdown]
# #### Pair plot

# %%
n = ['Price range', 'Aggregate rating', 'Votes', 'Average Cost for two']
sns.pairplot(final_data[n])
plt.show()

# %%
final_data['Restaurant Name'].value_counts()
# Out:
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64

# %% [markdown]
# #### Mean of Average Price for two people

# %%
final_data[["Average Cost for two"]].mean()
# Out:
# Average Cost for two    1199.210763
# dtype: float64

# %% [markdown]
# Thus the mean of Average Price for two people is 1199.210763

# %% [markdown]
# #### Let us fine differences in the rating of restaurants with and without table reservations

# %%
sns.boxplot(x = "Has Table booking", y = "Aggregate rating", data = final_data)
plt.title('The dependence of the rating on the availability of table reservations')
plt.show()

# %% [markdown]
# #### Observations:
# The restaurants that have table reservations have a rating of around 3.8 whereas non table bookings have aggregrate rating of around 3.1.
# The lower rating for restaurants may be primarily because customers had to return due unavailibility of a table or they might have rated the restaurant lower simply because it did not have table booking.

# %% [markdown]
# ### Rating vs Availabilty of Delivery

# %%
sns.boxplot(x = "Is delivering now", y = "Aggregate rating", data = final_data)
plt.title('The dependence of the rating on the availability of delivery')
plt.show()

# %% [markdown]
# #### Observations:
# 1. This box plot shows that restaurants have almost no connection with the rating when we take into consideration "The availability of Delivery".
# 2. Restaurants having delivery have a rating a little less than 3.5 whereas those not having delivery, have a rating of just above 3.2

# %% [markdown]
# #### Let us analyse Delhi

# %% [markdown]
# #### How many of such restaurants accept online delivery in Delhi

# %%
Delhi = data[(data.City == 'New Delhi')]
top_locality = Delhi.Locality.value_counts().head(10)
plt.figure(figsize=(12,6))
ax = sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])
plt.title('Resturants Online Delivery');

# %% [markdown]
# #### Observations:
# 1. Online Delivery seems to be on the higher side in Defence colony and Malviya Nagar. Other than Shahdara locality ,in other restaurants localities accept online delivery.

# %% [markdown]
# #### Location of Highly rated restaurants across New Delhi

# %%
Delhi['Rating text'].value_counts()
# Out:
# Average      2495
# Not rated    1425
# Good         1128
# Very Good     300
# Poor           97
# Excellent      28
# Name: Rating text, dtype: int64

# %% [markdown]
# ### Let's analyse Kolkata

# %%
k = data[(data.City == 'Kolkata')]
k.head(15)
# Out:
#       Restaurant ID                 Restaurant Name  Country Code     City  \
# 2398       18217475  Asia Kitchen by Mainland China             1  Kolkata
# 2399       18249144                       Hoppipola             1  Kolkata
# 2400       18017612                     Spice Kraft             1  Kolkata
# 2401       18377112                        Nawwarah             1  Kolkata
# 2402          20002              6 Ballygunge Place             1  Kolkata
# 2403       18343731                    Mumbai Local             1  Kolkata
# 2404          25664          Gabbar's Bar & Kitchen             1  Kolkata
# 2405          25587                    TGI Friday's             1  Kolkata
# 2406          24530                Santa's Fantasea             1  Kolkata
# 2407          20747                India Restaurant             1  Kolkata
# 2408          21220                   Flame & Grill             1  Kolkata
# ...

# %% [markdown]
# ### Highest number of restaurants under zomato services in Kolkata with online booking

# %% [markdown]
# #### Highest 25 costly restaurants for 2 in Kolkata:

# %%
k2=k.nlargest(25, 'Average Cost for two')
k2
# Out:
#       Restaurant ID                 Restaurant Name  Country Code     City  \
# 2413          24286                 The Irish House             1  Kolkata
# 2405          25587                    TGI Friday's             1  Kolkata
# 2416          24452             Sigree Global Grill             1  Kolkata
# 2414          20842                 Barbeque Nation             1  Kolkata
# 2409          25570                 Barbeque Nation             1  Kolkata
# 2408          21220                   Flame & Grill             1  Kolkata
# 2415       18259462                     Ocean Grill             1  Kolkata
# 2398       18217475  Asia Kitchen by Mainland China             1  Kolkata
# 2404          25664          Gabbar's Bar & Kitchen             1  Kolkata
# 2399       18249144                       Hoppipola             1  Kolkata
# 2403       18343731                    Mumbai Local             1  Kolkata
# ...

# %% [markdown]
# ## Conclusions

# %% [markdown]
#  Here’s a summary of conclusions:
#
# 1. The dataset is skewed towards India and doesn’t represent the complete data of restaurants worldwide.
#
#
# 2. Restaurants rating is categorized into six categories
#
#    1. Not Rated
#
#    2. Average
#
#    3. Good
#
#    4. Very Good
#
#    5. Excellent
#
#
# 3. They are also divided if they have table booking or not, or they have online ordering system.
#
#
# 4. There is no relation between cost and rating. Some of the best-rated restaurants are low on cost and vice versa.
#
#
# 5. Most of the restaurants are in India, to be precise 93.2%, this is understandable since Zomato is an Indian Company.
#
#
# 6. Our dataset has negligible null values. Only Cuisine column had some null values.
#
#
# 7. The highest number of ratings recieved is around 3.0 to 3.8, this may happen because the number of restaurants which have high rating is low in number. India has the most number of restaurants and many restaurants fall into the bucket of 3 to 4 rating range.
#
# 8. The highest number of cuisines are offered by Cafes.
#
#
# 9. The maximum number of restaurants falls in the 0 - 1000 price range and 2.5 to 4.0 rating.
