# %% [markdown]
# ### Insurance Claim Fraud Detection Project
# #### By: Amita Saini
# #### Internship Batch: 34

# %% [markdown]
# #### Project Description
# Insurance fraud is a huge problem in the industry. It's difficult to identify fraud claims. Machine Learning is in a unique position to help the Auto Insurance industry with this problem.
# In this project, you are provided a dataset which has the details of the insurance policy along with the customer details. It also has the details of the accident on the basis of which the claims have been made.
# In this example, you will be working with some auto insurance data to demonstrate how you can create a predictive model that predicts if an insurance claim is fraudulent or not.
#
# #### Independent Variables
# 1.	months_as_customer: Number of months of patronage
# 2.	age: the length of time a customer has lived or a thing has existed
# 3.	policy_number: It is a unique id given to the customer, to track the subscription status and other details of customer
# 4.	policy_bind_date:date which document that is given to customer after we accept your proposal for insurance
# 5.	policy_state: This identifies who is the insured, what risks or property are covered, the policy limits, and the policy period
# 6.	policy_csl: is basically Combined Single Limit
# 7.	policy_deductable: the amount of money that a customer is responsible for paying toward an insured loss
# 8.	policy_annual_premium: This means the amount of Regular Premium payable by the Policyholder in a Policy Year
# 9.	umbrella_limit: This means extra insurance that provides protection beyond existing limits and coverages of other policies
# 10.	insured_zip: It is the zip code where the insurance was made
# 11.	insured_sex: This refres to either of the two main categories (male and female) into which customer are divided on the basis of their reproductive functions
# 12.	insured_education_level: This refers to the Level of education of the customer
# 13.	insured_occupation: This refers Occupation of the customer
# 14.	insured_hobbies: This refers to an activity done regularly by customer in his/her leisure time for pleasure.
# 15.	insured_relationship: This whether customer is: single; or. married; or. in a de facto relationship (that is, living together but not married); or. in a civil partnership
# 16.	capital-gains: This refers to profit accrued due to insurance premium
# 17.	capital-loss: This refers to the losses incurred due to insurance claims
# 18.	incident_date: This refers to the date which claims where made by customers
# 19.	incident_type: This refers to the type of claim/vehicle damage made by customer
# 20.	collision_type: This refers to the area of damage on the vehicle
# 21.	incident_severity: This refers to the extent/level of damage
# 22.	authorities_contacted: This refers to the government agencies that were contacted after damage
# 23.	incident_state: This refers to the state at which the accident happened
# 24.	incident_city: This refers to the city at which the accident happened
# 25.	1ncident_location: This refers to the location at which the accident happened
# 26.	incident_hour_of_the_day: The period of the day which accident took place
# 27.	number_of_vehicles_involved: This refers to number of vehicles involved the accident
# 28.	property_damage: This refers to whether property was damaged or not
# 29.	bodily_injuries: This refers to injuries sustained
# 30.	witnesses: This refers to the number of witnesses involved
# 31.	police_report_available: This refers to whether the report on damage was documented or not
# 32.	total_claim_amount: This refers to the financial implications involved in claims
# 33.	injury_claim: This refers to physical injuries sustained
# 34.	property_claim: This refers to property damages during incident
# 35.	vehicle_claim: This refers to property damages during incident
# 36.	auto_make: This refers to the make of the vehicle
# 37.	auto_model: This refers to the model of the vehicle
# 38.	auto_year: This refers to the year which the vehicle was manufactured
# 39.	_c39:
# 40.	fraud_reported
#
# #### Dataset Link-
# •	https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/Automobile_insurance_fraud.csv

# %%
# Let us Import required library for performing EDA, Data Wrangling and data cleaning
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
# Let us Import Insurance Claims dataset CSV file
df = pd.read_csv(r'C:\Users\TCS\Desktop\Automobile_insurance_fraud.csv')

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
df.head()
# Out:
# No of Rows: 1000
# No of Columns: 40
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    25-01-2015  Single Vehicle Collision   Side Collision      Major Damage
# 1    21-01-2015             Vehicle Theft                ?      Minor Damage
# 2    22-02-2015   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    10-01-2015  Single Vehicle Collision  Front Collision      Major Damage
# 4    17-02-2015             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                  None             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported  _c39
# 0       2004              Y   NaN
# 1       2007              Y   NaN
# 2       2007              N   NaN
# 3       2014              Y   NaN
# 4       2009              N   NaN

# %%
# Sorting columns by datatypes
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['months_as_customer', 'age', 'policy_number', 'policy_deductable', 'umbrella_limit', 'insured_zip', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year'], float64: ['policy_annual_premium', '_c39'], object: ['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']}

# %%
# Let us check for entry which is repeated or duplicated in dataset
df.duplicated('policy_number').sum()
# Out:
# 0

# %%
# Let us check if any whitespace, 'NA' or '-' exist in dataset.
df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %%
df.isin(['?']).sum().any()
# Out:
# True

# %%
# Let us replace '?' with np.NaN
df=df.replace('?',np.NaN)

# %%
# Let us Find percentage of data missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                              Missing Values  % Missing data
# _c39                                   1000           100.0
# property_damage                         360            36.0
# police_report_available                 343            34.3
# collision_type                          178            17.8
# bodily_injuries                           0             0.0
# incident_state                            0             0.0
# incident_city                             0             0.0
# incident_location                         0             0.0
# incident_hour_of_the_day                  0             0.0
# number_of_vehicles_involved               0             0.0
# fraud_reported                            0             0.0
# auto_year                                 0             0.0
# auto_model                                0             0.0
# authorities_contacted                     0             0.0
# total_claim_amount                        0             0.0
# injury_claim                              0             0.0
# property_claim                            0             0.0
# vehicle_claim                             0             0.0
# auto_make                                 0             0.0
# witnesses                                 0             0.0
# months_as_customer                        0             0.0
# age                                       0             0.0
# insured_zip                               0             0.0
# policy_number                             0             0.0
# policy_bind_date                          0             0.0
# policy_state                              0             0.0
# policy_csl                                0             0.0
# policy_deductable                         0             0.0
# policy_annual_premium                     0             0.0
# umbrella_limit                            0             0.0
# insured_sex                               0             0.0
# incident_type                             0             0.0
# insured_education_level                   0             0.0
# insured_occupation                        0             0.0
# insured_hobbies                           0             0.0
# insured_relationship                      0             0.0
# capital-gains                             0             0.0
# capital-loss                              0             0.0
# incident_date                             0             0.0
# incident_severity                         0             0.0

# %% [markdown]
# #### Observations :
# 1. 'property_damage','police_report_available','collision_type' contain missing values.
# 2. _c39 column is with 100 % null value and will be droped in analysis.
# 3. Other missing value feature are categorical in nature. So, let us impute them with mode of that particular category.

# %%
# Missing value imputation
df['property_damage'].fillna(df['property_damage'].mode()[0],inplace=True)
df['police_report_available'].fillna(df['police_report_available'].mode()[0],inplace=True)
df['collision_type'].fillna(df['collision_type'].mode()[0],inplace=True)

# %%
# Droping unnecessary columns
df.drop(['_c39','incident_location','insured_zip','policy_number'],axis=1,inplace=True)

# %%
# Heatmap of missing value
sns.heatmap(df.isnull(),cmap="gist_earth")
plt.show()

# %% [markdown]
# #### Observations:
# 1. No Missing Value is Present now to proceed further.
# 2. Something details on Policy_csl column :
#
# In this dataset Policy_csl columns have numerical data separated by '/', resulting into object datatype.
# We will split this column into two CSL columns for person and accident.

# %%
# Spliting and extracting policy_csl at '/'
df['CSL_Personal']=df.policy_csl.str.split('/',expand=True)[0]
df['CSL_Accidental']=df.policy_csl.str.split('/',expand=True)[1]

# %%
# Dropping policy_csl column 
df.drop("policy_csl",axis=1,inplace=True)

# %%
# Converting Date columns from object type into datetime data type
df['policy_bind_date']=pd.to_datetime(df['policy_bind_date'])
df['incident_date']=pd.to_datetime(df['incident_date'])

# %%
# Extracting Day, Month and Year column from policy_bind_date
df['policy_bind_day'] = df['policy_bind_date'].dt.day
df['policy_bind_month'] = df['policy_bind_date'].dt.month
df['policy_bind_year'] = df['policy_bind_date'].dt.year

# Extracting Day, Month and Year column from incident_date
df['incident_day'] = df['incident_date'].dt.day
df['incident_month'] = df['incident_date'].dt.month
df['incident_year'] = df['incident_date'].dt.year

# %%
# As Extraction is completed. So,policy_bind_date and incident_date columns can be dropped
df.drop(['policy_bind_date','incident_date'],axis=1,inplace=True)

# %%
# Incident year is 2015 for all, so can be dropped here.
df.drop(['incident_year'],axis=1,inplace=True)

# %%
# Extracting age of the vehicle from auto_year by subtracting it from the year 2018
df['Automobile_Age']=2015 - df['auto_year']
# Droping auto year column
df.drop("auto_year",axis=1,inplace=True)

# %%
# Spliting feature in categorical and numerical variable
Category = ['policy_state',  'insured_sex', 'insured_education_level', 'insured_occupation', 
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted','incident_state', 'incident_city', 'property_damage','police_report_available',
            'auto_make','auto_model', 'fraud_reported']
    
Numerical = ['months_as_customer','CSL_Personal','CSL_Accidental', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'Automobile_Age','policy_annual_premium']

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'policy_bind_day', 'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month', 'Automobile_Age'], float64: ['policy_annual_premium'], object: ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported', 'CSL_Personal', 'CSL_Accidental']}

# %%
# Statistical Matrix
df.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_a4d73_row0_col0, #T_a4d73_row0_col2, #T_a4d73_row1_col0, #T_a4d73_row1_col2, #T_a4d73_row2_col0, #T_a4d73_row2_col2, #T_a4d73_row3_col0, #T_a4d73_row3_col2, #T_a4d73_row4_col0, #T_a4d73_row5_col0, #T_a4d73_row6_col0, #T_a4d73_row6_col1, #T_a4d73_row6_col5, #T_a4d73_row7_col0, #T_a4d73_row7_col2, #T_a4d73_row8_col0, #T_a4d73_row8_col2, #T_a4d73_row9_col0, #T_a4d73_row9_col2, #T_a4d73_row10_col0, #T_a4d73_row10_col2, #T_a4d73_row11_col0, #T_a4d73_row12_col0, #T_a4d73_row12_col2, #T_a4d73_row13_col0, #T_a4d73_row13_col2, #T_a4d73_row14_col0, #T_a4d73_row15_col0, #T_a4d73_row15_col2, #T_a4d73_row16_col0, #T_a4d73_row16_col2, #T_a4d73_row17_col0, #T_a4d73_row17_col2, #T_a4d73_row18_col0, #T_a4d73_row18_col2, #T_a4d73_row19_col0, #T_a4d73_row19_col2, #T_a4d73_row20_col0, #T_a4d73_row20_col2 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_a4d73_row0_col1, #T_a4d73_row1_col1, #T_a4d73_row2_col1, #T_a4d73_row3_col1, #T_a4d73_row7_col1, #T_a4d73_row8_col1, #T_a4d73_row9_col1, #T_a4d73_row10_col1, #T_a4d73_row15_col1, #T_a4d73_row16_col1, #T_a4d73_row17_col1, #T_a4d73_row18_col1, #T_a4d73_row19_col1, #T_a4d73_row20_col1 {
#   background-color: #fff3ef;
#   color: #000000;
# }
# #T_a4d73_row0_col5, #T_a4d73_row1_col5, #T_a4d73_row4_col5, #T_a4d73_row5_col5, #T_a4d73_row7_col5, #T_a4d73_row8_col5, #T_a4d73_row9_col5, #T_a4d73_row10_col5, #T_a4d73_row15_col5, #T_a4d73_row16_col5, #T_a4d73_row18_col5, #T_a4d73_row19_col5, #T_a4d73_row20_col5 {
#   background-color: #fbbabd;
#   color: #000000;
# }
# #T_a4d73_row2_col5 {
#   background-color: #fbb6bc;
#   color: #000000;
# }
# #T_a4d73_row3_col5 {
#   background-color: #fbb5bb;
#   color: #000000;
# }
# #T_a4d73_row4_col1, #T_a4d73_row4_col2, #T_a4d73_row11_col5 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_a4d73_row5_col1 {
#   background-color: #feefeb;
#   color: #000000;
# }
# #T_a4d73_row5_col2, #T_a4d73_row6_col2 {
#   background-color: #fff5f1;
#   color: #000000;
# }
# #T_a4d73_row11_col1 {
#   background-color: #feeae7;
#   color: #000000;
# }
# #T_a4d73_row11_col2, #T_a4d73_row14_col2 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# #T_a4d73_row12_col1, #T_a4d73_row13_col1 {
#   background-color: #fff2ee;
#   color: #000000;
# }
# #T_a4d73_row12_col5, #T_a4d73_row13_col5 {
#   background-color: #faa1b6;
#   color: #000000;
# }
# #T_a4d73_row14_col1 {
#   background-color: #feede9;
#   color: #000000;
# }
# #T_a4d73_row14_col5 {
#   background-color: #98017b;
#   color: #f1f1f1;
# }
# #T_a4d73_row17_col5 {
#   background-color: #fbb3bb;
#   color: #000000;
# }
# </style>
# <table id="T_a4d73_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4d73_level0_row0" class="row_heading level0 row0" >months_as_customer</th>
#       <td id="T_a4d73_row0_col0" class="data row0 col0" >1000.000000</td>
#       <td id="T_a4d73_row0_col1" class="data row0 col1" >203.954000</td>
#       <td id="T_a4d73_row0_col2" class="data row0 col2" >115.113174</td>
#       <td id="T_a4d73_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_a4d73_row0_col4" class="data row0 col4" >115.750000</td>
#       <td id="T_a4d73_row0_col5" class="data row0 col5" >199.500000</td>
#       <td id="T_a4d73_row0_col6" class="data row0 col6" >276.250000</td>
#       <td id="T_a4d73_row0_col7" class="data row0 col7" >479.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4d73_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_a4d73_row1_col0" class="data row1 col0" >1000.000000</td>
#       <td id="T_a4d73_row1_col1" class="data row1 col1" >38.948000</td>
#       <td id="T_a4d73_row1_col2" class="data row1 col2" >9.140287</td>
#       <td id="T_a4d73_row1_col3" class="data row1 col3" >19.000000</td>
#       <td id="T_a4d73_row1_col4" class="data row1 col4" >32.000000</td>
#       <td id="T_a4d73_row1_col5" class="data row1 col5" >38.000000</td>
#       <td id="T_a4d73_row1_col6" class="data row1 col6" >44.000000</td>
#       <td id="T_a4d73_row1_col7" class="data row1 col7" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4d73_level0_row2" class="row_heading level0 row2" >policy_deductable</th>
#       <td id="T_a4d73_row2_col0" class="data row2 col0" >1000.000000</td>
#       <td id="T_a4d73_row2_col1" class="data row2 col1" >1136.000000</td>
#       <td id="T_a4d73_row2_col2" class="data row2 col2" >611.864673</td>
#       <td id="T_a4d73_row2_col3" class="data row2 col3" >500.000000</td>
#       <td id="T_a4d73_row2_col4" class="data row2 col4" >500.000000</td>
#       <td id="T_a4d73_row2_col5" class="data row2 col5" >1000.000000</td>
#       <td id="T_a4d73_row2_col6" class="data row2 col6" >2000.000000</td>
#       <td id="T_a4d73_row2_col7" class="data row2 col7" >2000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4d73_level0_row3" class="row_heading level0 row3" >policy_annual_premium</th>
#       <td id="T_a4d73_row3_col0" class="data row3 col0" >1000.000000</td>
#       <td id="T_a4d73_row3_col1" class="data row3 col1" >1256.406150</td>
#       <td id="T_a4d73_row3_col2" class="data row3 col2" >244.167395</td>
#       <td id="T_a4d73_row3_col3" class="data row3 col3" >433.330000</td>
#       <td id="T_a4d73_row3_col4" class="data row3 col4" >1089.607500</td>
#       <td id="T_a4d73_row3_col5" class="data row3 col5" >1257.200000</td>
#       <td id="T_a4d73_row3_col6" class="data row3 col6" >1415.695000</td>
#       <td id="T_a4d73_row3_col7" class="data row3 col7" >2047.590000</td>
#     </tr>
#     <tr>
#       <th id="T_a4d73_level0_row4" class="row_heading level0 row4" >umbrella_limit</th>
#       <td id="T_a4d73_row4_col0" class="data row4 col0" >1000.000000</td>
#       <td id="T_a4d73_row4_col1" class="data row4 col1" >1101000.000000</td>
#       <td id="T_a4d73_row4_col2" class="data row4 col2" >2297406.598118</td>
#       <td id="T_a4d73_row4_col3" class="data row4 col3" >-1000000.000000</td>
#       <td id="T_a4d73_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_a4d73_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_a4d73_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_a4d73_row4_col7" class="data row4 col7" >10000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4d73_level0_row5" class="row_heading level0 row5" >capital-gains</th>
#       <td id="T_a4d73_row5_col0" class="data row5 col0" >1000.000000</td>
#       <td id="T_a4d73_row5_col1" class="data row5 col1" >25126.100000</td>
#       <td id="T_a4d73_row5_col2" class="data row5 col2" >27872.187708</td>
#       <td id="T_a4d73_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_a4d73_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_a4d73_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_a4d73_row5_col6" class="data row5 col6" >51025.000000</td>
#       <td id="T_a4d73_row5_col7" class="data row5 col7" >100500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4d73_level0_row6" class="row_heading level0 row6" >capital-loss</th>
#       <td id="T_a4d73_row6_col0" class="data row6 col0" >1000.000000</td>
#       <td id="T_a4d73_row6_col1" class="data row6 col1" >-26793.700000</td>
#       <td id="T_a4d73_row6_col2" class="data row6 col2" >28104.096686</td>
#       <td id="T_a4d73_row6_col3" class="data row6 col3" >-111100.000000</td>
#       <td id="T_a4d73_row6_col4" class="data row6 col4" >-51500.000000</td>
#       <td id="T_a4d73_row6_col5" class="data row6 col5" >-23250.000000</td>
#       <td id="T_a4d73_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_a4d73_row6_col7" class="data row6 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4d73_level0_row7" class="row_heading level0 row7" >incident_hou

# %%
df[Category].describe().T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# </style>
# <table id="T_bbbcd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >unique</th>
#       <th class="col_heading level0 col2" >top</th>
#       <th class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbbcd_level0_row0" class="row_heading level0 row0" >policy_state</th>
#       <td id="T_bbbcd_row0_col0" class="data row0 col0" >1000</td>
#       <td id="T_bbbcd_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_bbbcd_row0_col2" class="data row0 col2" >OH</td>
#       <td id="T_bbbcd_row0_col3" class="data row0 col3" >352</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row1" class="row_heading level0 row1" >insured_sex</th>
#       <td id="T_bbbcd_row1_col0" class="data row1 col0" >1000</td>
#       <td id="T_bbbcd_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_bbbcd_row1_col2" class="data row1 col2" >FEMALE</td>
#       <td id="T_bbbcd_row1_col3" class="data row1 col3" >537</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row2" class="row_heading level0 row2" >insured_education_level</th>
#       <td id="T_bbbcd_row2_col0" class="data row2 col0" >1000</td>
#       <td id="T_bbbcd_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_bbbcd_row2_col2" class="data row2 col2" >JD</td>
#       <td id="T_bbbcd_row2_col3" class="data row2 col3" >161</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row3" class="row_heading level0 row3" >insured_occupation</th>
#       <td id="T_bbbcd_row3_col0" class="data row3 col0" >1000</td>
#       <td id="T_bbbcd_row3_col1" class="data row3 col1" >14</td>
#       <td id="T_bbbcd_row3_col2" class="data row3 col2" >machine-op-inspct</td>
#       <td id="T_bbbcd_row3_col3" class="data row3 col3" >93</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row4" class="row_heading level0 row4" >insured_hobbies</th>
#       <td id="T_bbbcd_row4_col0" class="data row4 col0" >1000</td>
#       <td id="T_bbbcd_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_bbbcd_row4_col2" class="data row4 col2" >reading</td>
#       <td id="T_bbbcd_row4_col3" class="data row4 col3" >64</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row5" class="row_heading level0 row5" >insured_relationship</th>
#       <td id="T_bbbcd_row5_col0" class="data row5 col0" >1000</td>
#       <td id="T_bbbcd_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_bbbcd_row5_col2" class="data row5 col2" >own-child</td>
#       <td id="T_bbbcd_row5_col3" class="data row5 col3" >183</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row6" class="row_heading level0 row6" >incident_type</th>
#       <td id="T_bbbcd_row6_col0" class="data row6 col0" >1000</td>
#       <td id="T_bbbcd_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_bbbcd_row6_col2" class="data row6 col2" >Multi-vehicle Collision</td>
#       <td id="T_bbbcd_row6_col3" class="data row6 col3" >419</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row7" class="row_heading level0 row7" >collision_type</th>
#       <td id="T_bbbcd_row7_col0" class="data row7 col0" >1000</td>
#       <td id="T_bbbcd_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_bbbcd_row7_col2" class="data row7 col2" >Rear Collision</td>
#       <td id="T_bbbcd_row7_col3" class="data row7 col3" >470</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row8" class="row_heading level0 row8" >incident_severity</th>
#       <td id="T_bbbcd_row8_col0" class="data row8 col0" >1000</td>
#       <td id="T_bbbcd_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_bbbcd_row8_col2" class="data row8 col2" >Minor Damage</td>
#       <td id="T_bbbcd_row8_col3" class="data row8 col3" >354</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row9" class="row_heading level0 row9" >authorities_contacted</th>
#       <td id="T_bbbcd_row9_col0" class="data row9 col0" >1000</td>
#       <td id="T_bbbcd_row9_col1" class="data row9 col1" >5</td>
#       <td id="T_bbbcd_row9_col2" class="data row9 col2" >Police</td>
#       <td id="T_bbbcd_row9_col3" class="data row9 col3" >292</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row10" class="row_heading level0 row10" >incident_state</th>
#       <td id="T_bbbcd_row10_col0" class="data row10 col0" >1000</td>
#       <td id="T_bbbcd_row10_col1" class="data row10 col1" >7</td>
#       <td id="T_bbbcd_row10_col2" class="data row10 col2" >NY</td>
#       <td id="T_bbbcd_row10_col3" class="data row10 col3" >262</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row11" class="row_heading level0 row11" >incident_city</th>
#       <td id="T_bbbcd_row11_col0" class="data row11 col0" >1000</td>
#       <td id="T_bbbcd_row11_col1" class="data row11 col1" >7</td>
#       <td id="T_bbbcd_row11_col2" class="data row11 col2" >Springfield</td>
#       <td id="T_bbbcd_row11_col3" class="data row11 col3" >157</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row12" class="row_heading level0 row12" >property_damage</th>
#       <td id="T_bbbcd_row12_col0" class="data row12 col0" >1000</td>
#       <td id="T_bbbcd_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_bbbcd_row12_col2" class="data row12 col2" >NO</td>
#       <td id="T_bbbcd_row12_col3" class="data row12 col3" >698</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row13" class="row_heading level0 row13" >police_report_available</th>
#       <td id="T_bbbcd_row13_col0" class="data row13 col0" >1000</td>
#       <td id="T_bbbcd_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_bbbcd_row13_col2" class="data row13 col2" >NO</td>
#       <td id="T_bbbcd_row13_col3" class="data row13 col3" >686</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row14" class="row_heading level0 row14" >auto_make</th>
#       <td id="T_bbbcd_row14_col0" class="data row14 col0" >1000</td>
#       <td id="T_bbbcd_row14_col1" class="data row14 col1" >14</td>
#       <td id="T_bbbcd_row14_col2" class="data row14 col2" >Saab</td>
#       <td id="T_bbbcd_row14_col3" class="data row14 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row15" class="row_heading level0 row15" >auto_model</th>
#       <td id="T_bbbcd_row15_col0" class="data row15 col0" >1000</td>
#       <td id="T_bbbcd_row15_col1" class="data row15 col1" >39</td>
#       <td id="T_bbbcd_row15_col2" class="data row15 col2" >RAM</td>
#       <td id="T_bbbcd_row15_col3" class="data row15 col3" >43</td>
#     </tr>
#     <tr>
#       <th id="T_bbbcd_level0_row16" class="row_heading level0 row16" >fraud_reported</th>
#       <td id="T_bbbcd_row16_col0" class="data row16 col0" >1000</td>
#       <td id="T_bbbcd_row16_col1" class="data row16 col1" >2</td>
#       <td id="T_bbbcd_row16_col2" class="data row16 col2" >N</td>
#       <td id="T_bbbcd_row16_col3" class="data row16 col3" >753</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Starting with Enlisting Value counts & Sub-categories of different categorial features
for i in Category:
    print(i)
    print(df[i].value_counts())
    print("="*100)
# Out:
# policy_state
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64
# ====================================================================================================
# insured_sex
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64
# ====================================================================================================
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64
# ====================================================================================================
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64
# ====================================================================================================
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: insured_hobbies, dtype: int64
# ====================================================================================================
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: insured_relationship, dtype: int64
# ====================================================================================================
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64
# ====================================================================================================
# collision_type
# Rear Collision     470
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64
# ====================================================================================================
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: incident_severity, dtype: int64
# ====================================================================================================
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64
# ====================================================================================================
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64
# ====================================================================================================
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64
# ====================================================================================================
# property_damage
# NO     698
# YES    302
# Name: property_damage, dtype: int64
# ====================================================================================================
# police_report_available
# NO     686
# YES    314
# Name: police_report_available, dtype: int64
# ====================================================================================================
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: auto_make, dtype: int64
# ====================================================================================================
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: auto_model, dtype: int64
# ====================================================================================================
# fraud_reported
# N    753
# Y    247
# Name: fraud_reported, dtype: int64
# ====================================================================================================

# %%
# Exploring Target variable
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(14,7))
df['fraud_reported'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Fraud Cases Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('fraud_reported',data=df,ax=ax[1])
ax[1].set_title('Fraud Cases Count',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Fraud Cases",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Observations:
# 1. Almost 24.7 % cases are Fraud.
# 2. 'fraud_reported' is our target variable to be predicted. From count plot,dataset'imbalanced nature can be predicted.

# %%
# Exploring target variable against Independent features.
# Analysing Age vs Fraud
print('Minimum Age :',df.age.min(),'Years')
print('Maximum Age :',df.age.max(),'Years')
print('Average Age :',df.age.mean(),'Years')
# Out:
# Minimum Age : 19 Years
# Maximum Age : 64 Years
# Average Age : 38.948 Years

# %%
plt.figure(figsize=(7,6))
sns.histplot(df.age, kde=True, color='b')
plt.xlabel('Age',fontsize=16)
plt.title('Age Distribution', fontsize=18,fontweight ='bold')
plt.show()

# %%
# Spliting age in different age range
df['age_bins'] = pd.cut(df.age, bins = [0, 10, 20, 30, 40, 50, 60, 70], 
                          include_lowest = True, labels = ['0-10','11-20','21-30','31-40', '41-50', '51-60', '61-70'])

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df.age_bins, hue=df.fraud_reported)
plt.xlabel('Age',fontsize=18,fontweight ='bold')
plt.title('Age Distribution Vs Fraud Cases', fontsize=20,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Observations:
# 1. Maximum fraud cases comes from people with age group of 31-40 year and 41-50 year next.
# 2. Very Less cases in 60+ year old peoples.

# %%
# Policy State Vs Fraud cases
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['policy_state'].value_counts().plot.pie(explode=[0.03,0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder State Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['policy_state'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Statewise Fraud cases',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" State ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observations:
# 1. With minute difference, Almost same amout of cases from each state.
# 2. Maximum fraud cases come from state of Ohio.

# %%
# Insured Gender VS Fraud cases
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['insured_sex'].value_counts().plot.pie(explode=[0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder Gender Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['insured_sex'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Genderwise Fraud cases',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" Gender ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observations :
# 1. No of claims from female is higher than male insured.

# %%
# Education_level vs Fraud cases
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['insured_education_level'].value_counts().plot.pie(explode=[0.03,0.03,0.03,0.03,0.03,0.03,.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder Education_level Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['insured_education_level'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Fraud cases vs Policy-holder Education_level ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" Education_level ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observations :
# 1. Fraud claims are across every education backgroud, even in Masters,PhD. Education Level is not much important variable.

# %%
# Checking the insured occupation
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11, 8)
sns.countplot(df['insured_occupation'], palette = 'gist_earth')
plt.title('Different Types of Occupation of Insured Customers' ,fontsize=20,fontweight ='bold')
plt.xticks(rotation = 90)
plt.show()

# %%
# Checking the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15, 8)
sns.countplot(df['insured_hobbies'], palette = 'cool')
plt.title('Different Types of Hobbies of Insured Customers',fontsize=20,fontweight ='bold')
plt.xticks(rotation = 90)
plt.show()

# %%
# Checking the incident types
plt.rcParams['figure.figsize'] = (10,5)
sns.countplot(df['incident_type'], palette = 'Dark2')
plt.title('Different Types of Incidents',fontsize=20,fontweight ='bold')
plt.xlabel('Different Types of Incidents', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Dark2')
f,ax=plt.subplots(1,2,figsize=(20,11))
df['incident_type'].value_counts().plot.pie(explode=[0.03,.03,.03,.03],autopct='%3.1f%%',
                                          textprops ={ 'fontsize':14}, ax=ax[0],shadow=True)
ax[0].set_title('Incident Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('incident_type',data=df,ax=ax[1])
ax[1].set_title('Different Types of Incidents',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("incident_type",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,rotation=30,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
# Checking the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,7)
table = pd.crosstab(df['incident_type'], df['fraud_reported'])
table.plot(kind = 'bar')
plt.title('Fraud cases As per Incident Type',fontsize=20,fontweight ='bold')
plt.xlabel('Different Incidents', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Observations :
# 1.Most cases from Multi-vehicle and single vehicle collision.
# 2.One claim out of three claim is fraud in multi or single vehicle collision incident.

# %%
# Exploring different Collision
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2_r')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['collision_type'].value_counts().plot.pie(explode=[0.03,0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Collision Pie Chart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['collision_type'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Fraud cases in different Collision Type ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Collision Type ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation=0)
plt.tight_layout()
plt.show()

# %%
# Checking the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.set_palette('coolwarm')
table = pd.crosstab(df['incident_type'], df['collision_type'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True)
plt.title(' Incident Type VS Collision Type',fontsize=20,fontweight ='bold')
plt.xlabel('Collision', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %%
# Collision VS Incident Severity
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2_r')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['incident_severity'].value_counts().plot.pie(explode=[0.03,0.03,0.03,.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Severity of Collision Pie Chart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['incident_severity'], df['collision_type'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Incident Severity vs Collision Type ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Collision Type ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation=0)
plt.tight_layout()
plt.show()

# %%
# Checking another plot of Incident Type VS Severity of collision to gain more insight.
pd.crosstab(df['incident_type'], df['incident_severity']).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c6a1c_row0_col0, #T_c6a1c_row0_col2, #T_c6a1c_row2_col1, #T_c6a1c_row3_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_c6a1c_row0_col1 {
#   background-color: #108866;
#   color: #f1f1f1;
# }
# #T_c6a1c_row0_col3, #T_c6a1c_row1_col0, #T_c6a1c_row1_col1, #T_c6a1c_row1_col2, #T_c6a1c_row2_col3, #T_c6a1c_row3_col0, #T_c6a1c_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c6a1c_row1_col3 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_c6a1c_row2_col0 {
#   background-color: #158a66;
#   color: #f1f1f1;
# }
# #T_c6a1c_row2_col2 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_c6a1c_row3_col1 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# </style>
# <table id="T_c6a1c_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >incident_severity</th>
#       <th class="col_heading level0 col0" >Major Damage</th>
#       <th class="col_heading level0 col1" >Minor Damage</th>
#       <th class="col_heading level0 col2" >Total Loss</th>
#       <th class="col_heading level0 col3" >Trivial Damage</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >incident_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6a1c_level0_row0" class="row_heading level0 row0" >Multi-vehicle Collision</th>
#       <td id="T_c6a1c_row0_col0" class="data row0 col0" >144</td>
#       <td id="T_c6a1c_row0_col1" class="data row0 col1" >130</td>
#       <td id="T_c6a1c_row0_col2" class="data row0 col2" >145</td>
#       <td id="T_c6a1c_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c6a1c_level0_row1" class="row_heading level0 row1" >Parked Car</th>
#       <td id="T_c6a1c_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_c6a1c_row1_col1" class="data row1 col1" >42</td>
#       <td id="T_c6a1c_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c6a1c_row1_col3" class="data row1 col3" >42</td>
#     </tr>
#     <tr>
#       <th id="T_c6a1c_level0_row2" class="row_heading level0 row2" >Single Vehicle Collision</th>
#       <td id="T_c6a1c_row2_col0" class="data row2 col0" >132</td>
#       <td id="T_c6a1c_row2_col1" class="data row2 col1" >136</td>
#       <td id="T_c6a1c_row2_col2" class="data row2 col2" >135</td>
#       <td id="T_c6a1c_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c6a1c_level0_row3" class="row_heading level0 row3" >Vehicle Theft</th>
#       <td id="T_c6a1c_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_c6a1c_row3_col1" class="data row3 col1" >46</td>
#       <td id="T_c6a1c_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_c6a1c_row3_col3" class="data row3 col3" >48</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Checking the Incident Type VS incident_severity
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.set_palette('summer_r')
table = pd.crosstab(df['incident_type'], df['incident_severity'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar')
plt.title(' Incident Type VS incident_severity',fontsize=20,fontweight ='bold')
plt.xlabel('Collision', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %%
# Incident Type is important variable. Let us explore incident type by visualising incident type with Numerical features.
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.boxenplot(df['incident_type'], df['vehicle_claim'], palette = 'magma')
plt.title('Incident Type vs Vehicle Claim',fontsize=20,fontweight ='bold')
plt.xlabel('Incident Type', fontsize=16,fontweight='bold')
plt.ylabel('Vehicle Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11,7)
sns.stripplot(df['property_damage'], df['property_claim'], palette = 'bone')
plt.title('Incident Type vs Vehicle Claim',fontsize=20,fontweight ='bold')
plt.xlabel('Property Damage', fontsize=16,fontweight='bold')
plt.ylabel('Property claim', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11,7)
sns.swarmplot(df['policy_state'], df['total_claim_amount'], palette = 'copper')
plt.title('Total Claim Amount in Differnt State',fontsize=20,fontweight ='bold')
plt.xlabel('State', fontsize=16,fontweight='bold')
plt.ylabel('Total claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,9)
sns.boxplot(df['auto_make'], df['vehicle_claim'], palette = 'summer_r')
plt.title('Vehicle Claim Amount for different Automobile Makers',fontsize=20,fontweight ='bold')
plt.xlabel('Automobile Makers', fontsize=16,fontweight='bold')
plt.ylabel('Vehicle Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,9)
sns.scatterplot(df['policy_annual_premium'], df['total_claim_amount'], hue=df.fraud_reported, palette = 'Set1')
plt.title('Total Claim Amount VS Annual Premium',fontsize=20,fontweight ='bold')
plt.xlabel('Policy Annual Premium', fontsize=16,fontweight='bold')
plt.ylabel('Total Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,8)
sns.violinplot(df['incident_severity'], df['total_claim_amount'], hue=df.fraud_reported, palette = 'Set1')
plt.title('Incident Severity VS Total Claim Amount',fontsize=20,fontweight ='bold')
plt.xlabel('Incident Severity', fontsize=16,fontweight='bold')
plt.ylabel('Total Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# Checking truncated columns
pd.set_option('display.max_columns', None) 
df.head()
# Out:
#    months_as_customer  age policy_state  policy_deductable  \
# 0                 328   48           OH               1000
# 1                 228   42           IN               2000
# 2                 134   29           OH               2000
# 3                 256   41           IL               2000
# 4                 228   44           IL               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 4                1583.91         6000000        MALE               Associate
#
#   insured_occupation insured_hobbies insured_relationship  capital-gains  \
# 0       craft-repair        sleeping              husband          53300
# 1  machine-op-inspct         reading       other-relative              0
# 2              sales     board-games            own-child          35100
# 3       armed-forces     board-games            unmarried          48900
# 4              sales     board-games            unmarried          66000
#
#    capital-loss             incident_type   collision_type incident_severity  \
# 0             0  Single Vehicle Collision   Side Collision      Major Damage
# 1             0             Vehicle Theft   Rear Collision      Minor Damage
# 2             0   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3        -62400  Single Vehicle Collision  Front Collision      Major Damage
# 4        -46000             Vehicle Theft   Rear Collision      Minor Damage
#
#   authorities_contacted incident_state incident_city  \
# 0                Police             SC      Columbus
# 1                Police             VA     Riverwood
# 2                Police             NY      Columbus
# 3                Police             OH     Arlington
# 4                  None             NY     Arlington
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1              NO
# 2                         7                            3              NO
# 3                         5                            1              NO
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                      NO                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#   fraud_reported CSL_Personal CSL_Accidental  policy_bind_day  \
# 0              Y          250            500               17
# 1              Y          250            500               27
# 2              N          100            300                9
# 3              Y          250            500               25
# 4              N          500           1000                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  6              2000            22               2
# 3                  5              1990             1              10
# 4                  6              2014            17               2
#
#    Automobile_Age age_bins
# 0              11    41-50
# 1               8    41-50
# 2               8    21-30
# 3               1    41-50
# 4               6    41-50

# %%
# Encoding categorical data
Category = ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation',
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 
            'auto_make', 'auto_model', 'fraud_reported', 'CSL_Personal', 'CSL_Accidental']

# %%
# Now we can drop age_bins column 
df.drop("age_bins",axis=1,inplace=True)

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_sex  \
# 0                1406.91               0            1
# 1                1197.22         5000000            1
# 2                1413.14         5000000            0
# 3                1415.74         6000000            0
# 4                1583.91         6000000            1
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        4                   2               17
# 1                        4                   6               15
# 2                        6                  11                2
# 3                        6                   1                2
# 4                        0                  11                2
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0          53300             0              2
# 1                     2              0             0              3
# 2                     3          35100             0              0
# 3                     4          48900        -62400              2
# 4                     4          66000        -46000              3
#
#    collision_type  incident_severity  authorities_contacted  incident_state  \
# 0               2                  0                      4               4
# 1               1                  1                      4               5
# 2               1                  1                      4               1
# 3               0                  0                      4               2
# 4               1                  1                      2               1
#
#    incident_city  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0              1                         5                            1
# 1              5                         8                            1
# 2              1                         7                            3
# 3              0                         5                            1
# 4              0                        20                            1
#
#    property_damage  bodily_injuries  witnesses  police_report_available  \
# 0                1                1          2                        1
# 1                0                0          0                        0
# 2                0                2          3                        0
# 3                0                1          2                        0
# 4                0                0          1                        0
#
#    total_claim_amount  injury_claim  property_claim  vehicle_claim  auto_make  \
# 0               71610          6510           13020          52080         10
# 1                5070           780             780           3510          8
# 2               34650          7700            3850          23100          4
# 3               63400          6340            6340          50720          3
# 4                6500          1300             650           4550          0
#
#    auto_model  fraud_reported  CSL_Personal  CSL_Accidental  policy_bind_day  \
# 0           1               1             1               2               17
# 1          12               1             1               2               27
# 2          30               0             0               1                9
# 3          34               1             1               2               25
# 4          31               0             2               0                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  6              2000            22               2
# 3                  5              1990             1              10
# 4                  6              2014            17               2
#
#    Automobile_Age
# 0              11
# 1               8
# 2               8
# 3               1
# 4               6

# %%
Numerical = ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss',
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'policy_bind_day', 
             'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month', 'Automobile_Age','policy_annual_premium']

# %%
len(Numerical)
# Out:
# 21

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=21:
        ax=plt.subplot(7,3,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# #### As per Boxplot,outliers exist in dataset.

# %%
# Outliers removal using Zscore method
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (1000, 40)
# Shape of the dataframe after removing outliers:  (980, 40)
# Percentage of data loss post outlier removal:  2.0

# %%
# Skewness of features
plt.figure(figsize=(20,30),facecolor='white')
sns.set_palette('plasma')
plotnum=1
for col in Numerical:
    if plotnum<=21:
        plt.subplot(7,3,plotnum)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# #### Observations:
# Skewness is important feature for continous data. There is no relevence of skweness for discrete numerical feature like month and categorical feature.So we will ignore skewness present in discrete numerical and categorical feature.

# %%
# Let us ignore sknewness in target feature.
df[Numerical].skew()
# Out:
# months_as_customer             0.362608
# age                            0.475385
# policy_deductable              0.476090
# umbrella_limit                 1.801424
# capital-gains                  0.466619
# capital-loss                  -0.376884
# incident_hour_of_the_day      -0.039280
# number_of_vehicles_involved    0.509725
# bodily_injuries                0.003757
# witnesses                      0.026211
# total_claim_amount            -0.593593
# injury_claim                   0.271759
# property_claim                 0.361356
# vehicle_claim                 -0.620936
# policy_bind_day                0.028152
# policy_bind_month             -0.024643
# policy_bind_year               0.065022
# incident_day                   0.055443
# incident_month                 1.388336
# Automobile_Age                 0.054522
# policy_annual_premium          0.035964
# dtype: float64

# %% [markdown]
# #### Observations:
# 1. From above features 'umbrella_limit','total_claim_amount' and 'vehicle_claim' are continous variable with skew data.
# 2. The variable 'incident_month' is skewed but it is discrete in nature.So ignore it.

# %%
# Using yeo-johnson method to transform negatively skewed data.
# Making the skew less than or equal to +0.5 and -0.5 for better prediction using yeo-johnson method
skew=['total_claim_amount','vehicle_claim']

# Importing Powertransformer
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# Transfroming skew data
df[skew] = scaler.fit_transform(df[skew].values)

# %%
# Checking Skewness after transformation
df[skew].skew()
# Out:
# total_claim_amount   -0.508540
# vehicle_claim        -0.521805
# dtype: float64

# %% [markdown]
# #### Observations:
# For 'total_claim_amount','vehicle_claim' skewness has not been removed but it is reduced

# %%
# Corrleation
df.corr()
# Out:
#                              months_as_customer       age  policy_state  \
# months_as_customer                     1.000000  0.922960     -0.007183
# age                                    0.922960  1.000000     -0.020012
# policy_state                          -0.007183 -0.020012      1.000000
# policy_deductable                      0.031041  0.032036      0.017612
# policy_annual_premium                 -0.003814  0.005330      0.015089
# umbrella_limit                         0.018213  0.013256     -0.010921
# insured_sex                            0.059644  0.073790     -0.018002
# insured_education_level               -0.000731  0.001647     -0.027173
# insured_occupation                     0.006925  0.014798     -0.025357
# insured_hobbies                       -0.089358 -0.079099     -0.039501
# insured_relationship                   0.071492  0.076129     -0.017060
# capital-gains                          0.007468 -0.004529      0.068619
# capital-loss                           0.023041  0.012860     -0.031926
# incident_type                         -0.016746 -0.026286      0.032373
# collision_type                        -0.073031 -0.076325      0.049961
# incident_severity                     -0.064094 -0.064396     -0.028353
# authorities_contacted                  0.013782  0.018441     -0.014647
# incident_state                         0.015811  0.012644      0.019456
# incident_city                         -0.006601 -0.006685     -0.002809
# incident_hour_of_the_day               0.066198  0.083720      0.021926
# number_of_vehicles_involved            0.011831  0.020391     -0.045514
# property_damage                       -0.000630 -0.008239     -0.013576
# bodily_injuries                       -0.007674 -0.012254      0.012097
# witnesses                              0.063574  0.056360      0.025838
# police_report_available               -0.017200 -0.018135      0.065316
# total_claim_amount                     0.059338  0.068448     -0.015056
# injury_claim                           0.065062  0.077149     -0.048188
# property_claim                         0.036660  0.062375     -0.006420
# vehicle_claim                          0.056360  0.059129     -0.006411
# auto_make                              0.049734  0.033757      0.010259
# auto_model                             0.005130  0.015322     -0.018008
# fraud_reported                         0.021285  0.013279      0.034587
# CSL_Personal                          -0.021855 -0.013323      0.001653
# CSL_Accidental                         0.007121  0.011258      0.029007
# policy_bind_day                        0.050824  0.053147     -0.000583
# policy_bind_month                      0.004207  0.014492      0.073692
# policy_bind_year                      -0.041914 -0.031709     -0.003045
# incident_day                          -0.010538 -0.005843      0.016049
# incident_month                         0.019242  0.018221      0.027889
# Automobile_Age                        -0.000869 -0.005594      0.001160
#
#                              policy_deductable  policy_annual_premium  \
# months_as_customer                    0.031041              -0.003814
# age                                   0.032036               0.005330
# policy_state                          0.017612               0.015089
# policy_deductable                     1.000000              -0.008300
# policy_annual_premium                -0.008300               1.000000
# umbrella_limit                        0.013471              -0.014107
# insured_sex                          -0.006977               0.041312
# insured_education_level               0.014101              -0.021400
# insured_occupation                   -0.053888               0.027827
# insured_hobbies                      -0.001923              -0.014226
# insured_relationship                 -0.019000               0.004417
# capital-gains                         0.031673              -0.006807
# capital-loss                         -0.019601               0.033133
# incident_type                        -0.032291               0.051606
# collision_type                       -0.055984               0.032604
# incident_severity                    -0.016363              -0.013911
# authorities_contacted                 0.002769              -0.054425
# incident_state                        0.000647               0.048647
# incident_city                        -0.047304               0.047771
# incident_hour_of_the_day              0.064732              -0.006448
# number_of_vehicles_involved           0.046331              -0.044544
# property_damage                       0.013074               0.076447
# bodily_injuries                      -0.037263               0.027837
# witnesses                             0.071709               0.003433
# police_report_available               0.036275               0.032413
# total_claim_amount                    0.024385              -0.000944
# injury_claim                          0.038459              -0.024119
# property_claim                        0.071031              -0.014073
# vehicle_claim                         0.004874               0.009194
# auto_make                            -0.028032               0.009311
# auto_model                           -0.002591              -0.038226
# fraud_reported                        0.015774              -0.012686
# CSL_Personal                          0.009912               0.032654
# CSL_Accidental                       -0.014554              -0.001868
# policy_bind_day                       0.013395              -0.032681
# policy_bind_month                    -0.054208              -0.031608
# policy_bind_year                     -0.054041               0.002433
# incident_day                         -0.018115               0.018671
# incident_month                       -0.010288               0.009544
# Automobile_Age                       -0.030569               0.042446
#
#                              umbrella_limit  insured_sex  \
# months_as_customer                 0.018213     0.059644
# age                                0.013256     0.073790
# policy_state                      -0.010921    -0.018002
# policy_deductable                  0.013471    -0.006977
# policy_annual_premium             -0.014107     0.041312
# umbrella_limit                     1.000000     0.018068
# insured_sex                        0.018068     1.000000
# insured_education_level           -0.030887     0.010068
# insured_occupation                 0.003973    -0.007440
# insured_hobbies                   -0.034098    -0.020928
# insured_relationship               0.095972     0.004488
# capital-gains                     -0.022753    -0.019824
# capital-loss                      -0.025844    -0.030319
# incident_type                      0.034951     0.009540
# collision_type                     0.008716    -0.019044
# incident_severity                 -0.001297    -0.021242
# authorities_contacted              0.022396     0.019423
# incident_state                    -0.081479    -0.022522
# incident_city                      0.039685     0.009957
# incident_hour_of_the_day          -0.022571     0.012904
# number_of_vehicles_involved       -0.041298     0.018852
# property_damage                   -0.083258     0.032636
# bodily_injuries                    0.047719    -0.015199
# witnesses                         -0.001363     0.039343
# police_report_available           -0.036754     0.014179
# total_claim_amount                -0.047400    -0.016933
# injury_claim                      -0.046298     0.008472
# property_claim                    -0.021380    -0.008744
# vehicle_claim                     -0.048842    -0.023597
# auto_make                          0.012857     0.019996
# auto_model                         0.015360    -0.018657
# fraud_reported                     0.044729     0.020582
# CSL_Personal                       0.013504    -0.003405
# CSL_Accidental                     0.025418     0.071995
# policy_bind_day                   -0.030416     0.047690
# policy_bind_month                 -0.001072    -0.003125
# policy_bind_year                   0.049032    -0.031230
# incident_day                      -0.031948    -0.017208
# incident_month                     0.029210     0.036916
# Automobile_Age                    -0.027952     0.033336
#
#                              insured_education_level  insured_occupation  \
# months_as_customer                         -0.000731            0.006925
# age                                         0.001647            0.014798
# policy_state                               -0.027173           -0.025357
# policy_deductable                           0.014101           -0.053888
# policy_annual_premium                      -0.021400            0.027827
# umbrella_limit                             -0.030887            0.003973
# insured_sex                                 0.010068           -0.007440
# insured_education_level                     1.000000           -0.025394
# insured_occupation                         -0.025394            1.000000
# insured_hobbies                             0.025229           -0.010375
# insured_relationship                       -0.028673           -0.012135
# capital-gains                               0.044276            0.000409
# capital-loss                                0.037070           -0.016182
# incident_type                               0.005854            0.003755
# collision_type                             -0.022368            0.012390
# incident_severity                          -0.010929           -0.000513
# authorities_contacted                      -0.015500           -0.000998
# incident_state                             -0.007821           -0.020759
# incident_city                              -0.022502            0.003112
# incident_hour_of_the_day                   -0.053983           -0.021657
# number_of_vehicles_involved                 0.003279           -0.015647
# property_damage                            -0.050922           -0.020915
# bodily_injuries                            -0.017959           -0.000221
# witnesses                                   0.021747           -0.016435
# police_report_available                     0.055785           -0.024580
# total_claim_amount                          0.079642            0.008356
# injury_claim                                0.086600            0.024840
# property_claim                              0.062230            0.010040
# vehicle_claim                               0.072650            0.002591
# auto_make                                   0.060043            0.044331
# auto_model                                  0.042735            0.015152
# fraud_reported                              0.013116            0.000277
# CSL_Personal                                0.008337            0.016461
# CSL_Accidental                             -0.005150           -0.004376
# policy_bind_day                             0.018977            0.003377
# policy_bind_month                          -0.011963            0.020690
# policy_bind_year                            0.016874           -0.026467
# incident_day                               -0.051772           -0.020565
# incident_month                              0.069564            0.013989
# Automobile_Age                             -0.054438           -0.000915
#
#                              insured_hobbies  insured_relationship  \
# months_as_customer                 -0.089358              0.071492
# age                                -0.079099              0.076129
# policy_state                       -0.039501             -0.017060
# policy_deductable                  -0.001923             -0.019000
# policy_annual_premium              -0.014226              0.004417
# umbrella_limit                     -0.034098              0.095972
# insured_sex                        -0.020928              0.004488
# insured_education_level             0.025229             -0.028673
# insured_occupation                 -0.010375             -0.012135
# insured_hobbies                     1.000000             -0.095884
# insured_relationship               -0.095884              1.000000
# capital-gains                       0.054476             -0.020482
# capital-loss                       -0.030078             -0.062418
# incident_type                       0.012714              0.027740
# collision_type                      0.019817             -0.007310
# incident_severity                  -0.024033              0.014774
# authorities_contacted              -0.028086             -0.000307
# incident_state                      0.079743             -0.063668
# incident_city                       0.019611             -0.005335
# incident_hour_of_the_day            0.017177              0.005602
# number_of_vehicles_involved         0.007490             -0.044342
# property_damage                     0.034044             -0.037415
# bodily_injuries                     0.026890              0.001363
# witnesses                          -0.036967             -0.001631
# police_report_available            -0.034683             -0.018228
# total_claim_amount                 -0.001466              0.004031
# injury_claim                        0.031374              0.031088
# property_claim                      0.010616              0.005691
# vehicle_claim                      -0.013752             -0.004344
# auto_make                          -0.000984             -0.030718
# auto_model                          0.034818              0.057003
# fraud_reported                     -0.048181              0.026575
# CSL_Personal                       -0.003695             -0.034603
# CSL_Accidental                      0.035959             -0.037223
# policy_bind_day                     0.035344              0.008887
# policy_bind_month                  -0.003806              0.039564
# policy_bind_year                   -0.020370             -0.006341
# incident_day                        0.016051             -0.078348
# incident_month                     -0.001147              0.045237
# Automobile_Age                      0.018361              0.020051
#
#                              capital-gains  capital-loss  incident_type  \
# months_as_customer                0.007468      0.023041      -0.016746
# age                              -0.004529      0.012860      -0.026286
# policy_state                      0.068619     -0.031926       0.032373
# policy_deductable                 0.031673     -0.019601      -0.032291
# policy_annual_premium            -0.006807      0.033133       0.051606
# umbrella_limit                   -0.022753     -0.025844       0.034951
# insured_sex                      -0.019824     -0.030319       0.009540
# insured_education_level           0.044276      0.037070       0.005854
# insured_occupation                0.000409     -0.016182       0.003755
# insured_hobbies                   0.054476     -0.030078       0.012714
# insured_relationship             -0.020482     -0.062418       0.027740
# capital-gains                     1.000000     -0.047387      -0.042178
# capital-loss                     -0.047387      1.000000       0.017490
# incident_type                    -0.042178      0.017490       1.000000
# collision_type                   -0.012077      0.034342      -0.076280
# incident_severity                -0.010312     -0.011845       0.156929
# authorities_contacted            -0.046192      0.012790       0.095919
# incident_state                    0.017182     -0.053073       0.035372
# incident_city                    -0.035961     -0.035095       0.024138
# incident_hour_of_the_day         -0.016288     -0.029339      -0.134586
# number_of_vehicles_involved       0.057932     -0.007438      -0.894148
# property_damage                   0.000039      0.018424       0.022777
# bodily_injuries                   0.047421     -0.031480      -0.011155
# witnesses                        -0.018701     -0.037671      -0.007484
# police_report_available          -0.012984     -0.036964       0.016545
# total_claim_amount                0.010549     -0.035532      -0.266770
# injury_claim                      0.021430     -0.044049      -0.222032
# property_claim                   -0.009262     -0.021848      -0.220058
# vehicle_claim                     0.011751     -0.032407      -0.260443
# auto_make                         0.057197     -0.051431      -0.039905
# auto_model                        0.049813     -0.040877      -0.041414
# fraud_reported                   -0.014993     -0.017617      -0.040893
# CSL_Personal                      0.009786     -0.035589       0.005180
# CSL_Accidental                   -0.004870      0.010440       0.004640
# policy_bind_day                   0.001224     -0.030852      -0.006095
# policy_bind_month                -0.008909      0.003280       0.037715
# policy_bind_year                  0.039978     -0.026457      -0.048389
# incident_day                      0.017699     -0.018464       0.013663
# incident_month                    0.037077      0.030991      -0.037530
# Automobile_Age                   -0.029903      0.062780       0.044207
#
#                              collision_type  incident_severity  \
# months_as_customer                -0.073031          -0.064094
# age                               -0.076325          -0.064396
# policy_state                       0.049961          -0.028353
# policy_deductable                 -0.055984          -0.016363
# policy_annual_premium              0.032604          -0.013911
# umbrella_limit                     0.008716          -0.001297
# insured_sex                       -0.019044          -0.021242
# insured_education_level           -0.022368          -0.010929
# insured_occupation                 0.012390          -0.000513
# insured_hobbies                    0.019817          -0.024033
# insured_relationship              -0.007310           0.014774
# capital-gains                     -0.012077          -0.010312
# capital-loss                       0.034342          -0.011845
# incident_type                     -0.076280           0.156929
# collision_type                     1.000000          -0.014718
# incident_severity                 -0.014718           1.000000
# authorities_contacted              0.059102           0.164854
# incident_state                     0.032457           0.065112
# incident_city                      0.029188          -0.018072
# incident_hour_of_the_day           0.038185          -0.075029
# number_of_vehicles_involved        0.084722          -0.166737
# property_damage                    0.001873          -0.041874
# bodily_injuries                   -0.020533          -0.018126
# witnesses                         -0.048104          -0.005564
# police_report_available            0.052468          -0.004103
# total_claim_amount                -0.017216          -0.360119
# injury_claim                      -0.021370          -0.273482
# property_claim                    -0.014697          -0.303125
# vehicle_claim                     -0.014407          -0.356637
# auto_make                         -0.005907          -0.005527
# auto_model                         0.023922          -0.049808
# fraud_reported                    -0.016776          -0.401808
# CSL_Personal                       0.028139           0.017195
# CSL_Accidental                    -0.017626           0.011673
# policy_bind_day                    0.021369          -0.037886
# policy_bind_month                 -0.043560          -0.036582
# policy_bind_year                   0.027177           0.005476
# incident_day                       0.045649           0.019190
# incident_month                    -0.021175          -0.013664
# Automobile_Age                    -0.003079           0.009588
#
#                              authorities_contacted  incident_state  \
# months_as_customer                        0.013782        0.015811
# age                                       0.018441        0.012644
# policy_state                             -0.014647        0.019456
# policy_deductable                         0.002769        0.000647
# policy_annual_premium                    -0.054425        0.048647
# umbrella_limit                            0.022396       -0.081479
# insured_sex                               0.019423       -0.022522
# insured_education_level                  -0.015500       -0.007821
# insured_occupation                       -0.000998       -0.020759
# insured_hobbies                          -0.028086        0.079743
# insured_relationship                     -0.000307       -0.063668
# capital-gains                            -0.046192        0.017182
# capital-loss                              0.012790       -0.053073
# incident_type                             0.095919        0.035372
# collision_type                            0.059102        0.032457
# incident_severity                         0.164854        0.065112
# authorities_contacted                     1.000000        0.024742
# incident_state                            0.024742        1.000000
# incident_city                            -0.006286        0.017458
# incident_hour_of_the_day                 -0.058827       -0.033427
# number_of_vehicles_involved              -0.077550       -0.031451
# property_damage                          -0.000945       -0.044609
# bodily_injuries                           0.038572       -0.003194
# witnesses                                -0.001834        0.011652
# police_report_available                   0.046644        0.044762
# total_claim_amount                       -0.167270       -0.037109
# injury_claim                             -0.145290       -0.013219
# property_claim                           -0.120224       -0.021514
# vehicle_claim                            -0.166711       -0.043901
# auto_make                                -0.027299        0.073847
# auto_model                                0.018781       -0.042899
# fraud_reported                           -0.043636       -0.052027
# CSL_Personal                              0.051030        0.035804
# CSL_Accidental                            0.010505        0.005663
# policy_bind_day                          -0.036420        0.040592
# policy_bind_month                        -0.048840        0.001721
# policy_bind_year                         -0.032755       -0.028406
# incident_day                             -0.014321        0.018364
# incident_month                            0.006895       -0.027527
# Automobile_Age                           -0.078044        0.016908
#
#                              incident_city  incident_hour_of_the_day  \
# months_as_customer               -0.006601                  0.066198
# age                              -0.006685                  0.083720
# policy_state                     -0.002809                  0.021926
# policy_deductable                -0.047304                  0.064732
# policy_annual_premium             0.047771                 -0.006448
# umbrella_limit                    0.039685                 -0.022571
# insured_sex                       0.009957                  0.012904
# insured_education_level          -0.022502                 -0.053983
# insured_occupation                0.003112                 -0.021657
# insured_hobbies                   0.019611                  0.017177
# insured_relationship             -0.005335                  0.005602
# capital-gains                    -0.035961                 -0.016288
# capital-loss                     -0.035095                 -0.029339
# incident_type                     0.024138                 -0.134586
# collision_type                    0.029188                  0.038185
# incident_severity                -0.018072                 -0.075029
# authorities_contacted            -0.006286                 -0.058827
# incident_state                    0.017458                 -0.033427
# incident_city                     1.000000                  0.014158
# incident_hour_of_the_day          0.014158                  1.000000
# number_of_vehicles_involved      -0.011232                  0.120599
# property_damage                   0.008900                  0.056306
# bodily_injuries                   0.042923                 -0.033120
# witnesses                         0.008201                  0.006843
# police_report_available           0.016568                  0.040425
# total_claim_amount                0.040296                  0.216020
# injury_claim                      0.043915                  0.173753
# property_claim                    0.037697                  0.176317
# vehicle_claim                     0.034817                  0.212482
# auto_make                         0.005561                 -0.007946
# auto_model                        0.024292                 -0.059031
# fraud_reported                   -0.039434                  0.004326
# CSL_Personal                      0.014380                  0.003918
# CSL_Accidental                   -0.023156                  0.006180
# policy_bind_day                   0.009023                 -0.005947
# policy_bind_month                 0.070199                 -0.001737
# policy_bind_year                 -0.009456                  0.039484
# incident_day                     -0.047271                 -0.030009
# incident_month                    0.036482                  0.045796
# Automobile_Age                   -0.062385                 -0.016597
#
#                              number_of_vehicles_involved  property_damage  \
# months_as_customer                              0.011831        -0.000630
# age                                             0.020391        -0.008239
# policy_state                                   -0.045514        -0.013576
# policy_deductable                               0.046331         0.013074
# policy_annual_premium                          -0.044544         0.076447
# umbrella_limit                                 -0.041298        -0.083258
# insured_sex                                     0.018852         0.032636
# insured_education_level                         0.003279        -0.050922
# insured_occupation                             -0.015647        -0.020915
# insured_hobbies                                 0.007490         0.034044
# insured_relationship                           -0.044342        -0.037415
# capital-gains                                   0.057932         0.000039
# capital-loss                                   -0.007438         0.018424
# incident_type                                  -0.894148         0.022777
# collision_type                                  0.084722         0.001873
# incident_severity                              -0.166737        -0.041874
# authorities_contacted                          -0.077550        -0.000945
# incident_state                                 -0.031451        -0.044609
# incident_city                                  -0.011232         0.008900
# incident_hour_of_the_day                        0.120599         0.056306
# number_of_vehicles_involved                     1.000000        -0.016866
# property_damage                                -0.016866         1.000000
# bodily_injuries                                 0.013094         0.001651
# witnesses                                      -0.014410        -0.017017
# police_report_available                        -0.006301        -0.023685
# total_claim_amount                              0.264344         0.055756
# injury_claim                                    0.221080         0.049066
# property_claim                                  0.218462         0.039663
# vehicle_claim                                   0.257673         0.055031
# auto_make                                       0.017986        -0.009738
# auto_model                                      0.036555        -0.055786
# fraud_reported                                  0.043535         0.025897
# CSL_Personal                                   -0.014658        -0.024497
# CSL_Accidental                                 -0.004455         0.006881
# policy_bind_day                                 0.003681        -0.010019
# policy_bind_month                              -0.042271         0.004688
# policy_bind_year                                0.023556         0.019078
# incident_day                                   -0.021352         0.018573
# incident_month                                  0.030693        -0.008613
# Automobile_Age                                 -0.028295         0.039792
#
#                              bodily_injuries  witnesses  \
# months_as_customer                 -0.007674   0.063574
# age                                -0.012254   0.056360
# policy_state                        0.012097   0.025838
# policy_deductable                  -0.037263   0.071709
# policy_annual_premium               0.027837   0.003433
# umbrella_limit                      0.047719  -0.001363
# insured_sex                        -0.015199   0.039343
# insured_education_level            -0.017959   0.021747
# insured_occupation                 -0.000221  -0.016435
# insured_hobbies                     0.026890  -0.036967
# insured_relationship                0.001363  -0.001631
# capital-gains                       0.047421  -0.018701
# capital-loss                       -0.031480  -0.037671
# incident_type                      -0.011155  -0.007484
# collision_type                     -0.020533  -0.048104
# incident_severity                  -0.018126  -0.005564
# authorities_contacted               0.038572  -0.001834
# incident_state                     -0.003194   0.011652
# incident_city                       0.042923   0.008201
# incident_hour_of_the_day           -0.033120   0.006843
# number_of_vehicles_involved         0.013094  -0.014410
# property_damage                     0.001651  -0.017017
# bodily_injuries                     1.000000   0.001083
# witnesses                           0.001083   1.000000
# police_report_available             0.007072   0.051720
# total_claim_amount                  0.045814  -0.013857
# injury_claim                        0.044349  -0.025951
# property_claim                      0.036189   0.048616
# vehicle_claim                       0.042858  -0.025670
# auto_make                           0.029512   0.005529
# auto_model                          0.025879  -0.005816
# fraud_reported                      0.039184   0.049974
# CSL_Personal                        0.001385   0.071361
# CSL_Accidental                     -0.020053  -0.012073
# policy_bind_day                    -0.046463   0.002109
# policy_bind_month                  -0.031546  -0.012699
# policy_bind_year                    0.025891   0.051345
# incident_day                       -0.027563   0.018054
# incident_month                      0.046969  -0.027943
# Automobile_Age                      0.016984  -0.047636
#
#                              police_report_available  total_claim_amount  \
# months_as_customer                         -0.017200            0.059338
# age                                        -0.018135            0.068448
# policy_state                                0.065316           -0.015056
# policy_deductable                           0.036275            0.024385
# policy_annual_premium                       0.032413           -0.000944
# umbrella_limit                             -0.036754           -0.047400
# insured_sex                                 0.014179           -0.016933
# insured_education_level                     0.055785            0.079642
# insured_occupation                         -0.024580            0.008356
# insured_hobbies                            -0.034683           -0.001466
# insured_relationship                       -0.018228            0.004031
# capital-gains                              -0.012984            0.010549
# capital-loss                               -0.036964           -0.035532
# incident_type                               0.016545           -0.266770
# collision_type                              0.052468           -0.017216
# incident_severity                          -0.004103           -0.360119
# authorities_contacted                       0.046644           -0.167270
# incident_state                              0.044762           -0.037109
# incident_city                               0.016568            0.040296
# incident_hour_of_the_day                    0.040425            0.216020
# number_of_vehicles_involved                -0.006301            0.264344
# property_damage                            -0.023685            0.055756
# bodily_injuries                             0.007072            0.045814
# witnesses                                   0.051720           -0.013857
# police_report_available                     1.000000            0.041533
# total_claim_amount                          0.041533            1.000000
# injury_claim                                0.034192            0.807017
# property_claim                              0.012104            0.812584
# vehicle_claim                               0.046547            0.981046
# auto_make                                   0.061661           -0.053016
# auto_model                                 -0.018469            0.044617
# fraud_reported                             -0.023867            0.162420
# CSL_Personal                               -0.008979           -0.053435
# CSL_Accidental                              0.065395           -0.019772
# policy_bind_day                            -0.026116           -0.014298
# policy_bind_month                           0.012336            0.060147
# policy_bind_year                           -0.012390           -0.001971
# incident_day                                0.025115           -0.039623
# incident_month                             -0.022882            0.053928
# Automobile_Age                              0.022763            0.040099
#
#                              injury_claim  property_claim  vehicle_claim  \
# months_as_customer               0.065062        0.036660       0.056360
# age                              0.077149        0.062375       0.059129
# policy_state                    -0.048188       -0.006420      -0.006411
# policy_deductable                0.038459        0.071031       0.004874
# policy_annual_premium           -0.024119       -0.014073       0.009194
# umbrella_limit                  -0.046298       -0.021380      -0.048842
# insured_sex                      0.008472       -0.008744      -0.023597
# insured_education_level          0.086600        0.062230       0.072650
# insured_occupation               0.024840        0.010040       0.002591
# insured_hobbies                  0.031374        0.010616      -0.013752
# insured_relationship             0.031088        0.005691      -0.004344
# capital-gains                    0.021430       -0.009262       0.011751
# capital-loss                    -0.044049       -0.021848      -0.032407
# incident_type                   -0.222032       -0.220058      -0.260443
# collision_type                  -0.021370       -0.014697      -0.014407
# incident_severity               -0.273482       -0.303125      -0.356637
# authorities_contacted           -0.145290       -0.120224      -0.166711
# incident_state                  -0.013219       -0.021514      -0.043901
# incident_city                    0.043915        0.037697       0.034817
# incident_hour_of_the_day         0.173753        0.176317       0.212482
# number_of_vehicles_involved      0.221080        0.218462       0.257673
# property_damage                  0.049066        0.039663       0.055031
# bodily_injuries                  0.044349        0.036189       0.042858
# witnesses                       -0.025951        0.048616      -0.025670
# police_report_available          0.034192        0.012104       0.046547
# total_claim_amount               0.807017        0.812584       0.981046
# injury_claim                     1.000000        0.567714       0.720168
# property_claim                   0.567714        1.000000       0.730148
# vehicle_claim                    0.720168        0.730148       1.000000
# auto_make                       -0.031745       -0.043108      -0.054549
# auto_model                       0.042930        0.054570       0.037127
# fraud_reported                   0.088812        0.139101       0.169284
# CSL_Personal                    -0.080098       -0.042876      -0.042728
# CSL_Accidental                   0.000055       -0.015800      -0.023797
# policy_bind_day                  0.002086       -0.014316      -0.017020
# policy_bind_month                0.020589        0.056362       0.064575
# policy_bind_year                 0.000805       -0.002393      -0.002153
# incident_day                    -0.023289       -0.015431      -0.045824
# incident_month                   0.015556        0.042797       0.061002
# Automobile_Age                   0.018872        0.018923       0.046500
#
#                              auto_make  auto_model  fraud_reported  \
# months_as_customer            0.049734    0.005130        0.021285
# age                           0.033757    0.015322        0.013279
# policy_state                  0.010259   -0.018008        0.034587
# policy_deductable            -0.028032   -0.002591        0.015774
# policy_annual_premium         0.009311   -0.038226       -0.012686
# umbrella_limit                0.012857    0.015360        0.044729
# insured_sex                   0.019996   -0.018657        0.020582
# insured_education_level       0.060043    0.042735        0.013116
# insured_occupation            0.044331    0.015152        0.000277
# insured_hobbies              -0.000984    0.034818       -0.048181
# insured_relationship         -0.030718    0.057003        0.026575
# capital-gains                 0.057197    0.049813       -0.014993
# capital-loss                 -0.051431   -0.040877       -0.017617
# incident_type                -0.039905   -0.041414       -0.040893
# collision_type               -0.005907    0.023922       -0.016776
# incident_severity            -0.005527   -0.049808       -0.401808
# authorities_contacted        -0.027299    0.018781       -0.043636
# incident_state                0.073847   -0.042899       -0.052027
# incident_city                 0.005561    0.024292       -0.039434
# incident_hour_of_the_day     -0.007946   -0.059031        0.004326
# number_of_vehicles_involved   0.017986    0.036555        0.043535
# property_damage              -0.009738   -0.055786        0.025897
# bodily_injuries               0.029512    0.025879        0.039184
# witnesses                     0.005529   -0.005816        0.049974
# police_report_available       0.061661   -0.018469       -0.023867
# total_claim_amount           -0.053016    0.044617        0.162420
# injury_claim                 -0.031745    0.042930        0.088812
# property_claim               -0.043108    0.054570        0.139101
# vehicle_claim                -0.054549    0.037127        0.169284
# auto_make                     1.000000   -0.173016       -0.032206
# auto_model                   -0.173016    1.000000       -0.002825
# fraud_reported               -0.032206   -0.002825        1.000000
# CSL_Personal                 -0.009395    0.042905       -0.032509
# CSL_Accidental               -0.025250   -0.001119        0.042864
# policy_bind_day              -0.010551   -0.005126        0.063705
# policy_bind_month            -0.041099   -0.007687       -0.032606
# policy_bind_year             -0.004028    0.029770        0.003317
# incident_day                  0.049668   -0.043141       -0.058330
# incident_month               -0.031146    0.028307        0.024143
# Automobile_Age                0.003440   -0.038604       -0.001152
#
#                              CSL_Personal  CSL_Accidental  policy_bind_day  \
# months_as_customer              -0.021855        0.007121         0.050824
# age                             -0.013323        0.011258         0.053147
# policy_state                     0.001653        0.029007        -0.000583
# policy_deductable                0.009912       -0.014554         0.013395
# policy_annual_premium            0.032654       -0.001868        -0.032681
# umbrella_limit                   0.013504        0.025418        -0.030416
# insured_sex                     -0.003405        0.071995         0.047690
# insured_education_level          0.008337       -0.005150         0.018977
# insured_occupation               0.016461       -0.004376         0.003377
# insured_hobbies                 -0.003695        0.035959         0.035344
# insured_relationship            -0.034603       -0.037223         0.008887
# capital-gains                    0.009786       -0.004870         0.001224
# capital-loss                    -0.035589        0.010440        -0.030852
# incident_type                    0.005180        0.004640        -0.006095
# collision_type                   0.028139       -0.017626         0.021369
# incident_severity                0.017195        0.011673        -0.037886
# authorities_contacted            0.051030        0.010505        -0.036420
# incident_state                   0.035804        0.005663         0.040592
# incident_city                    0.014380       -0.023156         0.009023
# incident_hour_of_the_day         0.003918        0.006180        -0.005947
# number_of_vehicles_involved     -0.014658       -0.004455         0.003681
# property_damage                 -0.024497        0.006881        -0.010019
# bodily_injuries                  0.001385       -0.020053        -0.046463
# witnesses                        0.071361       -0.012073         0.002109
# police_report_available         -0.008979        0.065395        -0.026116
# total_claim_amount              -0.053435       -0.019772        -0.014298
# injury_claim                    -0.080098        0.000055         0.002086
# property_claim                  -0.042876       -0.015800        -0.014316
# vehicle_claim                   -0.042728       -0.023797        -0.017020
# auto_make                       -0.009395       -0.025250        -0.010551
# auto_model                       0.042905       -0.001119        -0.005126
# fraud_reported                  -0.032509        0.042864         0.063705
# CSL_Personal                     1.000000       -0.456766         0.013568
# CSL_Accidental                  -0.456766        1.000000         0.014486
# policy_bind_day                  0.013568        0.014486         1.000000
# policy_bind_month               -0.041283        0.032044         0.042319
# policy_bind_year                -0.019409       -0.000831         0.001074
# incident_day                    -0.002278        0.031458         0.025739
# incident_month                  -0.010904       -0.030397         0.004014
# Automobile_Age                   0.030370       -0.029835        -0.021052
#
#                              policy_bind_month  policy_bind_year  \
# months_as_customer                    0.004207         -0.041914
# age                                   0.014492         -0.031709
# policy_state                          0.073692         -0.003045
# policy_deductable                    -0.054208         -0.054041
# policy_annual_premium                -0.031608          0.002433
# umbrella_limit                       -0.001072          0.049032
# insured_sex                          -0.003125         -0.031230
# insured_education_level              -0.011963          0.016874
# insured_occupation                    0.020690         -0.026467
# insured_hobbies                      -0.003806         -0.020370
# insured_relationship                  0.039564         -0.006341
# capital-gains                        -0.008909          0.039978
# capital-loss                          0.003280         -0.026457
# incident_type                         0.037715         -0.048389
# collision_type                       -0.043560          0.027177
# incident_severity                    -0.036582          0.005476
# authorities_contacted                -0.048840         -0.032755
# incident_state                        0.001721         -0.028406
# incident_city                         0.070199         -0.009456
# incident_hour_of_the_day             -0.001737          0.039484
# number_of_vehicles_involved          -0.042271          0.023556
# property_damage                       0.004688          0.019078
# bodily_injuries                      -0.031546          0.025891
# witnesses                            -0.012699          0.051345
# police_report_available               0.012336         -0.012390
# total_claim_amount                    0.060147         -0.001971
# injury_claim                          0.020589          0.000805
# property_claim                        0.056362         -0.002393
# vehicle_claim                         0.064575         -0.002153
# auto_make                            -0.041099         -0.004028
# auto_model                           -0.007687          0.029770
# fraud_reported                       -0.032606          0.003317
# CSL_Personal                         -0.041283         -0.019409
# CSL_Accidental                        0.032044         -0.000831
# policy_bind_day                       0.042319          0.001074
# policy_bind_month                     1.000000         -0.004808
# policy_bind_year                     -0.004808          1.000000
# incident_day                         -0.040712          0.055181
# incident_month                        0.015708         -0.064748
# Automobile_Age                       -0.001076         -0.016244
#
#                              incident_day  incident_month  Automobile_Age
# months_as_customer              -0.010538        0.019242       -0.000869
# age                             -0.005843        0.018221       -0.005594
# policy_state                     0.016049        0.027889        0.001160
# policy_deductable               -0.018115       -0.010288       -0.030569
# policy_annual_premium            0.018671        0.009544        0.042446
# umbrella_limit                  -0.031948        0.029210       -0.027952
# insured_sex                     -0.017208        0.036916        0.033336
# insured_education_level         -0.051772        0.069564       -0.054438
# insured_occupation              -0.020565        0.013989       -0.000915
# insured_hobbies                  0.016051       -0.001147        0.018361
# insured_relationship            -0.078348        0.045237        0.020051
# capital-gains                    0.017699        0.037077       -0.029903
# capital-loss                    -0.018464        0.030991        0.062780
# incident_type                    0.013663       -0.037530        0.044207
# collision_type                   0.045649       -0.021175       -0.003079
# incident_severity                0.019190       -0.013664        0.009588
# authorities_contacted           -0.014321        0.006895       -0.078044
# incident_state                   0.018364       -0.027527        0.016908
# incident_city                   -0.047271        0.036482       -0.062385
# incident_hour_of_the_day        -0.030009        0.045796       -0.016597
# number_of_vehicles_involved     -0.021352        0.030693       -0.028295
# property_damage                  0.018573       -0.008613        0.039792
# bodily_injuries                 -0.027563        0.046969        0.016984
# witnesses                        0.018054       -0.027943       -0.047636
# police_report_available          0.025115       -0.022882        0.022763
# total_claim_amount              -0.039623        0.053928        0.040099
# injury_claim                    -0.023289        0.015556        0.018872
# property_claim                  -0.015431        0.042797        0.018923
# vehicle_claim                   -0.045824        0.061002        0.046500
# auto_make                        0.049668       -0.031146        0.003440
# auto_model                      -0.043141        0.028307       -0.038604
# fraud_reported                  -0.058330        0.024143       -0.001152
# CSL_Personal                    -0.002278       -0.010904        0.030370
# CSL_Accidental                   0.031458       -0.030397       -0.029835
# policy_bind_day                  0.025739        0.004014       -0.021052
# policy_bind_month               -0.040712        0.015708       -0.001076
# policy_bind_year                 0.055181       -0.064748       -0.016244
# incident_day                     1.000000       -0.666135       -0.012973
# incident_month                  -0.666135        1.000000        0.031696
# Automobile_Age                  -0.012973        0.031696        1.000000

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', cmap="gist_stern")
plt.show()

# %%
plt.figure(figsize=(22,10))
df.corr()['fraud_reported'].sort_values(ascending=False).drop(['fraud_reported']).plot(kind='bar',color='y')
plt.xlabel('Feature',fontsize=14,fontweight='bold')
plt.ylabel('Target',fontsize=14,fontweight='bold')
plt.title('Correlation of features v/s Target Variable Fraud_reported',fontsize=20,fontweight='bold')
plt.show()

# %% [markdown]
# #### Observation:
# 1. incident_severity is correlated with target variable with correlation of 0.4.
# 2. Other variable are poorly correlated with target variable.
# 3. injury_claim,property_claim,vehicle_claim are highly correlated with each other.
# 4. incident_hour_of_the_day is highly negative correlated with incident type.

# %%
# Balanceing Imbalanced target feature
df.fraud_reported.value_counts()
# Out:
# 0    740
# 1    240
# Name: fraud_reported, dtype: int64

# %%
# Target variable data is Imbalanced in nature. So, target variable need to be balanced
# Balancing using SMOTE
from imblearn.over_sampling import SMOTE

# %%
# Splitting data in target and dependent feature
X = df.drop(['fraud_reported'], axis =1)
Y = df['fraud_reported']

# %%
# Oversampling using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 1    740
# 0    740
# Name: fraud_reported, dtype: int64

# %% [markdown]
# #### Observations:
# Resolved the class imbalanced problem and now all the categories have same data ensuring that the ML model does not get biased towards any category.

# %%
# Standard Scaling
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
# Checking Multicollinearity between features using variance_inflation_factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(X_scale,i) for i in range(len(X.columns))]
vif["Features"] = X.columns
vif
# Out:
#       VIF values                     Features
# 0       7.266668           months_as_customer
# 1       7.237602                          age
# 2       1.072878                 policy_state
# 3       1.065195            policy_deductable
# 4       1.046633        policy_annual_premium
# 5       1.060604               umbrella_limit
# 6       1.074114                  insured_sex
# 7       1.058296      insured_education_level
# 8       1.031642           insured_occupation
# 9       1.077690              insured_hobbies
# 10      1.059287         insured_relationship
# 11      1.071089                capital-gains
# 12      1.073590                 capital-loss
# 13      3.821099                incident_type
# 14      1.085463               collision_type
# 15      1.381942            incident_severity
# 16      1.139971        authorities_contacted
# 17      1.081451               incident_state
# 18      1.067342                incident_city
# 19      1.122571     incident_hour_of_the_day
# 20      3.686695  number_of_vehicles_involved
# 21      1.061457              property_damage
# 22      1.059379              bodily_injuries
# 23      1.066394                    witnesses
# 24      1.099105      police_report_available
# 25  42521.647762           total_claim_amount
# 26   1705.271767                 injury_claim
# 27   1666.591379               property_claim
# 28  21095.867126                vehicle_claim
# 29      1.080119                    auto_make
# 30      1.075860                   auto_model
# 31      1.240342                 CSL_Personal
# 32      1.231281               CSL_Accidental
# 33      1.036457              policy_bind_day
# 34      1.047605            policy_bind_month
# 35      1.034741             policy_bind_year
# 36      1.825465                 incident_day
# 37      1.828341               incident_month
# 38      1.064893               Automobile_Age

# %% [markdown]
# #### Addressing Multicollinearity :
# 1. Removing Some of highly correlated features. But this will not work here as most of input features are correlated with each other either moderated or poorly.
# 2. Scaled Data and then apply PCA.
# Second way for further investigation is better option as For some Independent feature VIF is exceed permissible limit of 10.

# %%
# PCA
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %% [markdown]
# #### Observations:
#
# As per the Plot, 28 principal components attribute for 90% of variation in the data. So, first 28 components are picked for our prediction.

# %%
pca_new = PCA(n_components=28)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(28))

# %% [markdown]
# ### Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1036, 28)
# Training target vector size: (1036,)
# Test feature matrix size: (444, 28)
# Test target vector size: (444,)

# %% [markdown]
# ### Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.7972972972972973 on Random_state 233

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=9, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.7792792792792793
#
#
# Confusion matrix of Logistics Regression :
#  [[176  51]
#  [ 47 170]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       227
#            1       0.77      0.78      0.78       217
#
#     accuracy                           0.78       444
#    macro avg       0.78      0.78      0.78       444
# weighted avg       0.78      0.78      0.78       444

# %%
# Finding Optimal value of n_neighbors for KNN
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.4931969619160719
# RMSE value for k=  2 is: 0.44010645722790037
# RMSE value for k=  3 is: 0.5155247479663472
# RMSE value for k=  4 is: 0.483977514182461
# RMSE value for k=  5 is: 0.5348233690070359
# RMSE value for k=  6 is: 0.5155247479663472
# RMSE value for k=  7 is: 0.5575040903982775
# RMSE value for k=  8 is: 0.5284688063445933
# RMSE value for k=  9 is: 0.5595203866375765
# RMSE value for k=  10 is: 0.5473111999123986
# RMSE value for k=  11 is: 0.5694947974514994
# RMSE value for k=  12 is: 0.5431804903022982
# RMSE value for k=  13 is: 0.5734359849441164
# RMSE value for k=  14 is: 0.5554804754071547
# RMSE value for k=  15 is: 0.5889370482885644
# RMSE value for k=  16 is: 0.5655261442407591
# RMSE value for k=  17 is: 0.5831724359827805
# RMSE value for k=  18 is: 0.5694947974514994
# RMSE value for k=  19 is: 0.5889370482885644
# RMSE value for k=  20 is: 0.5792974931635606

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(20), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# ### Observations:
# At k=2, minimum RMSE value is approx 0.4745789978762495, and moves up on further increasing the k value. So, it can be said that k=2 will give us the best result in this case

# %% [markdown]
# ### Applying other classification algorithm

# %%
model=[ LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]
        
for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('============================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix LogisticRegression() is
#
#
# Accuracy Score :
#  0.7792792792792793
#
#
# Confusion matrix :
#  [[176  51]
#  [ 47 170]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       227
#            1       0.77      0.78      0.78       217
#
#     accuracy                           0.78       444
#    macro avg       0.78      0.78      0.78       444
# weighted avg       0.78      0.78      0.78       444
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.8400900900900901
#
#
# Confusion matrix :
#  [[191  36]
#  [ 35 182]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84       227
#            1       0.83      0.84      0.84       217
#
#     accuracy                           0.84       444
#    macro avg       0.84      0.84      0.84       444
# weighted avg       0.84      0.84      0.84       444
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.759009009009009
#
#
# Confusion matrix :
#  [[174  53]
#  [ 54 163]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76       227
#            1       0.75      0.75      0.75       217
#
#     accuracy                           0.76       444
#    macro avg       0.76      0.76      0.76       444
# weighted avg       0.76      0.76      0.76       444
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.704954954954955
#
#
# Confusion matrix :
#  [[150  77]
#  [ 54 163]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.74      0.66      0.70       227
#            1       0.68      0.75      0.71       217
#
#     accuracy                           0.70       444
#    macro avg       0.71      0.71      0.70       444
# weighted avg       0.71      0.70      0.70       444
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix KNeighborsClassifier(n_neighbors=3) is
#
#
# Accuracy Score :
#  0.7342342342342343
#
#
# Confusion matrix :
#  [[116 111]
#  [  7 210]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.94      0.51      0.66       227
#            1       0.65      0.97      0.78       217
#
#     accuracy                           0.73       444
#    macro avg       0.80      0.74      0.72       444
# weighted avg       0.80      0.73      0.72       444
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.8085585585585585
#
#
# Confusion matrix :
#  [[186  41]
#  [ 44 173]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81       227
#            1       0.81      0.80      0.80       217
#
#     accuracy                           0.81       444
#    macro avg       0.81      0.81      0.81       444
# weighted avg       0.81      0.81      0.81       444
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix ExtraTreesClassifier() is
#
#
# Accuracy Score :
#  0.8445945945945946
#
#
# Confusion matrix :
#  [[190  37]
#  [ 32 185]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       227
#            1       0.83      0.85      0.84       217
#
#     accuracy                           0.84       444
#    macro avg       0.84      0.84      0.84       444
# weighted avg       0.84      0.84      0.84       444
#
#
#
# ============================================================================================================

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, principle_x, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('============================================================================================================')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.60810811 0.68918919 0.78716216 0.8277027  0.83108108]
# Mean Score : 0.7486486486486487
# Std deviation : 0.08696552300412257
#
#
# ============================================================================================================
#
#
# Cross Validation Score SVC() :
#
# Score : [0.58108108 0.73986486 0.87837838 0.89527027 0.92567568]
# Mean Score : 0.8040540540540541
# Std deviation : 0.12843171011717894
#
#
# ============================================================================================================
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.57432432 0.69256757 0.85472973 0.86148649 0.85472973]
# Mean Score : 0.7675675675675675
# Std deviation : 0.11574385462358841
#
#
# ============================================================================================================
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.58445946 0.63851351 0.69594595 0.80067568 0.68581081]
# Mean Score : 0.6810810810810811
# Std deviation : 0.07168533626959377
#
#
# ============================================================================================================
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=3) :
#
# Score : [0.67905405 0.71283784 0.76689189 0.77364865 0.76351351]
# Mean Score : 0.7391891891891892
# Std deviation : 0.03703294488120196
#
#
# ============================================================================================================
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.63175676 0.73648649 0.875      0.89189189 0.88175676]
# Mean Score : 0.8033783783783784
# Std deviation : 0.10299123765093177
#
#
# ============================================================================================================
#
#
# Cross Validation Score ExtraTreesClassifier() :
#
# Score : [0.66891892 0.75675676 0.90540541 0.90878378 0.91891892]
# Mean Score : 0.8317567567567569
# Std deviation : 0.10108975248251373
#
#
# ============================================================================================================

# %% [markdown]
# ### Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
             'max_features':['auto','sqrt','log2'],
              'min_samples_split':[3,5,8,11],
              'max_depth' : [10,20,30],
              'n_estimators' : [100,200,300,400]
             }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 1/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 1/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.822 total time=   0.8s
# [CV 2/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 2/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.768 total time=   0.8s
# [CV 3/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 3/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.787 total time=   0.7s
# [CV 4/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 4/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.739 total time=   0.8s
# [CV 5/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 5/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.816 total time=   0.8s
# [CV 1/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 1/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.812 total time=   1.7s
# [CV 2/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 2/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.754 total time=   1.9s
# [CV 3/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 3/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.787 total time=   2.5s
# [CV 4/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 4/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.739 total time=   3.1s
# [CV 5/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 5/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.812 total time=   1.9s
# [CV 1/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 1/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.817 total time=   2.6s
# [CV 2/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 2/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.739 total time=   2.9s
# [CV 3/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 3/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.778 total time=   2.5s
# [CV 4/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 4/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.754 total time=   2.4s
# [CV 5/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 5/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.826 total time=   2.0s
# [CV 1/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 1/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.817 total time=   3.1s
# [CV 2/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 2/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.744 total time=   4.5s
# [CV 3/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 3/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.807 total time=   2.9s
# [CV 4/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 4/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.749 total time=   2.7s
# [CV 5/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 5/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.816 total time=   2.7s
# [CV 1/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 1/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.798 total time=   0.6s
# [CV 2/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 2/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.725 total time=   0.6s
# [CV 3/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 3/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.783 total time=   0.7s
# [CV 4/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 4/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.739 total time=   0.6s
# [CV 5/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 5/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.841 total time=   0.6s
# [CV 1/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 1/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.822 total time=   1.3s
# [CV 2/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 2/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.739 total time=   1.4s
# [CV 3/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 3/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.783 total time=   1.3s
# [CV 4/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 4/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.763 total time=   1.3s
# [CV 5/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 5/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.836 total time=   1.4s
# [CV 1/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 1/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.817 total time=   2.1s
# [CV 2/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 2/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.758 total time=   2.0s
# [CV 3/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 3/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.797 total time=   2.1s
# [CV 4/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 4/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.725 total time=   2.0s
# [CV 5/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 5/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.797 total time=   2.0s
# [CV 1/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 1/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.812 total time=   2.8s
# [CV 2/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 2/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.763 total time=   3.1s
# [CV 3/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 3/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.787 total time=   2.8s
# [CV 4/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 4/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.754 total time=   2.7s
# [CV 5/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 5/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.816 total time=   2.7s
# [CV 1/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 1/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.798 total time=   0.6s
# [CV 2/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 2/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.754 total time=   0.6s
# [CV 3/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 3/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.797 total time=   0.6s
# [CV 4/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 4/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.744 total time=   0.6s
# [CV 5/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 5/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.812 total time=   0.6s
# [CV 1/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 1/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.812 total time=   1.4s
# [CV 2/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 2/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.749 total time=   1.3s
# [CV 3/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 3/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.812 total time=   1.3s
# [CV 4/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 4/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.725 total time=   1.3s
# [CV 5/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 5/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.812 total time=   1.3s
# [CV 1/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 1/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.822 total time=   2.0s
# [CV 2/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 2/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.754 total time=   2.0s
# [CV 3/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 3/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.778 total time=   2.0s
# [CV 4/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 4/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.720 total time=   2.8s
# [CV 5/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 5/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.792 total time=   2.5s
# [CV 1/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 1/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.832 total time=   2.6s
# [CV 2/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 2/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.749 total time=   2.7s
# [CV 3/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 3/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.792 total time=   2.7s
# [CV 4/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 4/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.739 total time=   3.1s
# [CV 5/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 5/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.802 total time=   4.2s
# [CV 1/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 1/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.808 total time=   0.6s
# [CV 2/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 2/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.773 total time=   0.6s
# [CV 3/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 3/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.754 total time=   0.6s
# [CV 4/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 4/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.744 total time=   0.6s
# [CV 5/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 5/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.797 total time=   0.6s
# [CV 1/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 1/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.788 total time=   1.3s
# [CV 2/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 2/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.734 total time=   1.4s
# [CV 3/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 3/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.797 total time=   1.4s
# [CV 4/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 4/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.729 total time=   1.4s
# [CV 5/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 5/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.792 total time=   1.4s
# [CV 1/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 1/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.808 total time=   2.1s
# [CV 2/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 2/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.739 total time=   2.1s
# [CV 3/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 3/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.797 total time=   2.4s
# [CV 4/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 4/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.729 total time=   2.8s
# [CV 5/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 5/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.807 total time=   2.1s
# [CV 1/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 1/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.812 total time=   3.0s
# [CV 2/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 2/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.749 total time=   3.2s
# [CV 3/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 3/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.802 total time=   2.9s
# [CV 4/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 4/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.744 total time=   3.8s
# [CV 5/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 5/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.797 total time=   3.0s
# [CV 1/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 1/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.808 total time=   0.7s
# [CV 2/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 2/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.763 total time=   0.7s
# [CV 3/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 3/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.773 total time=   0.7s
# [CV 4/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 4/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.758 total time=   0.7s
# [CV 5/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 5/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.821 total time=   0.9s
# [CV 1/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 1/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.817 total time=   1.5s
# [CV 2/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 2/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.763 total time=   1.4s
# [CV 3/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 3/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.807 total time=   1.4s
# [CV 4/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 4/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.744 total time=   1.4s
# [CV 5/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 5/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.816 total time=   1.4s
# [CV 1/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 1/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.832 total time=   2.1s
# [CV 2/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 2/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.754 total time=   2.0s
# [CV 3/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 3/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.812 total time=   2.0s
# [CV 4/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 4/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.739 total time=   1.9s
# [CV 5/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 5/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.821 total time=   2.0s
# [CV 1/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 1/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.822 total time=   2.6s
# [CV 2/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 2/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.739 total time=   3.0s
# [CV 3/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 3/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.807 total time=   3.3s
# [CV 4/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 4/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.758 total time=   3.0s
# [CV 5/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 5/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.787 total time=   2.6s
# [CV 1/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 1/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.798 total time=   0.6s
# [CV 2/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 2/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.739 total time=   0.6s
# [CV 3/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 3/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.787 total time=   0.6s
# [CV 4/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 4/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.729 total time=   0.6s
# [CV 5/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 5/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.792 total time=   0.6s
# [CV 1/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 1/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.808 total time=   1.3s
# [CV 2/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 2/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.744 total time=   1.3s
# [CV 3/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 3/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.792 total time=   1.3s
# [CV 4/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 4/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.763 total time=   1.2s
# [CV 5/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 5/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.792 total time=   1.3s
# [CV 1/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 1/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.827 total time=   1.9s
# [CV 2/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 2/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.734 total time=   1.9s
# [CV 3/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 3/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.807 total time=   1.9s
# [CV 4/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 4/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.749 total time=   1.9s
# [CV 5/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 5/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.812 total time=   1.9s
# [CV 1/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 1/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.808 total time=   2.6s
# [CV 2/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 2/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.744 total time=   2.6s
# [CV 3/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 3/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.807 total time=   3.1s
# [CV 4/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 4/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.739 total time=   2.6s
# [CV 5/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 5/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.826 total time=   2.6s
# [CV 1/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 1/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.798 total time=   0.6s
# [CV 2/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 2/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.773 total time=   0.6s
# [CV 3/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 3/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.802 total time=   0.6s
# [CV 4/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 4/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.729 total time=   0.6s
# [CV 5/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 5/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.792 total time=   0.6s
# [CV 1/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 1/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.832 total time=   1.3s
# [CV 2/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 2/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.754 total time=   1.5s
# [CV 3/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 3/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.783 total time=   1.3s
# [CV 4/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 4/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.725 total time=   2.4s
# [CV 5/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 5/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.802 total time=   2.3s
# [CV 1/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 1/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.837 total time=   2.9s
# [CV 2/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 2/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.758 total time=   2.2s
# [CV 3/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 3/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.812 total time=   2.7s
# [CV 4/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 4/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.725 total time=   2.2s
# [CV 5/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 5/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.802 total time=   2.5s
# [CV 1/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 1/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.808 total time=   3.6s
# [CV 2/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 2/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.744 total time=   4.1s
# [CV 3/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 3/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.797 total time=   3.2s
# [CV 4/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 4/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.754 total time=   3.3s
# [CV 5/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 5/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.797 total time=   4.7s
# [CV 1/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 1/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.793 total time=   0.9s
# [CV 2/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 2/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.744 total time=   0.8s
# [CV 3/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 3/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.787 total time=   0.6s
# [CV 4/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 4/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.739 total time=   0.7s
# [CV 5/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 5/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.802 total time=   0.8s
# [CV 1/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 1/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.808 total time=   1.6s
# [CV 2/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 2/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.739 total time=   1.5s
# [CV 3/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 3/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.797 total time=   1.4s
# [CV 4/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 4/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.720 total time=   1.4s
# [CV 5/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 5/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.797 total time=   1.4s
# [CV 1/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 1/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.817 total time=   2.2s
# [CV 2/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 2/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.739 total time=   2.2s
# [CV 3/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 3/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.797 total time=   1.9s
# [CV 4/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 4/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.729 total time=   1.9s
# [CV 5/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 5/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.792 total time=   2.0s
# [CV 1/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 1/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.817 total time=   2.5s
# [CV 2/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 2/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.744 total time=   2.5s
# [CV 3/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 3/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.797 total time=   2.5s
# [CV 4/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 4/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.758 total time=   2.5s
# [CV 5/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 5/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.802 total time=   2.6s
# [CV 1/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 1/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.846 total time=   0.8s
# [CV 2/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 2/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.768 total time=   1.0s
# [CV 3/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 3/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.797 total time=   1.1s
# [CV 4/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 4/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.763 total time=   1.5s
# [CV 5/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 5/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.802 total time=   0.9s
# [CV 1/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 1/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.841 total time=   1.9s
# [CV 2/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 2/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.734 total time=   1.4s
# [CV 3/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 3/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.812 total time=   1.2s
# [CV 4/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 4/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.763 total time=   1.2s
# [CV 5/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 5/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.831 total time=   1.3s
# [CV 1/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 1/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.817 total time=   1.8s
# [CV 2/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 2/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.749 total time=   1.8s
# [CV 3/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 3/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.812 total time=   1.9s
# [CV 4/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 4/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.754 total time=   1.8s
# [CV 5/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 5/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.816 total time=   1.9s
# [CV 1/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 1/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.822 total time=   2.5s
# [CV 2/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 2/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.763 total time=   2.5s
# [CV 3/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 3/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.812 total time=   2.5s
# [CV 4/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 4/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.744 total time=   2.6s
# [CV 5/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 5/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.841 total time=   2.5s
# [CV 1/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 1/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.793 total time=   0.6s
# [CV 2/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 2/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.768 total time=   0.6s
# [CV 3/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 3/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.821 total time=   0.6s
# [CV 4/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 4/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.744 total time=   0.6s
# [CV 5/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 5/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.787 total time=   0.6s
# [CV 1/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 1/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.841 total time=   1.2s
# [CV 2/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 2/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.773 total time=   1.2s
# [CV 3/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 3/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.778 total time=   1.3s
# [CV 4/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 4/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.754 total time=   1.3s
# [CV 5/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 5/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.787 total time=   1.4s
# [CV 1/5; 39/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 1/5; 39/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.803 total time=   1.8s
# ...
# [CV 1/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 1/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.846 total time=   0.8s
# [CV 2/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 2/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.768 total time=   0.8s
# [CV 3/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 3/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.816 total time=   0.8s
# [CV 4/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 4/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.768 total time=   0.8s
# [CV 5/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 5/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.841 total time=   1.8s
# [CV 1/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 1/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.837 total time=   1.8s
# [CV 2/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 2/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.768 total time=   1.7s
# [CV 3/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 3/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.812 total time=   1.7s
# [CV 4/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 4/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.763 total time=   1.6s
# [CV 5/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 5/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.845 total time=   1.7s
# [CV 1/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 1/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.837 total time=   2.6s
# [CV 2/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 2/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.787 total time=   2.7s
# [CV 3/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 3/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.807 total time=   2.5s
# [CV 4/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 4/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.773 total time=   2.5s
# [CV 5/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 5/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.845 total time=   2.5s
# [CV 1/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 1/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.837 total time=   3.4s
# [CV 2/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 2/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.758 total time=   3.8s
# [CV 3/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 3/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.807 total time=   4.2s
# [CV 4/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 4/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.763 total time=   4.0s
# [CV 5/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 5/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.831 total time=   4.2s
# [CV 1/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 1/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.827 total time=   0.9s
# [CV 2/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 2/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.783 total time=   0.8s
# [CV 3/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 3/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.792 total time=   0.7s
# [CV 4/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 4/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.749 total time=   0.7s
# [CV 5/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 5/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.831 total time=   0.8s
# [CV 1/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 1/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.841 total time=   1.6s
# [CV 2/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 2/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.754 total time=   1.7s
# [CV 3/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 3/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.807 total time=   1.6s
# [CV 4/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 4/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.744 total time=   1.9s
# [CV 5/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 5/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.836 total time=   1.7s
# [CV 1/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 1/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.827 total time=   2.5s
# [CV 2/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 2/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.758 total time=   2.4s
# [CV 3/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 3/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.816 total time=   2.3s
# [CV 4/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 4/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.763 total time=   3.0s
# [CV 5/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 5/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.821 total time=   2.5s
# [CV 1/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 1/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.808 total time=   4.1s
# [CV 2/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 2/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.754 total time=   3.8s
# [CV 3/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 3/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.821 total time=   3.1s
# [CV 4/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 4/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.754 total time=   3.2s
# [CV 5/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 5/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.826 total time=   3.5s
# [CV 1/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 1/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.803 total time=   0.9s
# [CV 2/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 2/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.763 total time=   0.9s
# [CV 3/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 3/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.807 total time=   0.9s
# [CV 4/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 4/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.749 total time=   0.9s
# [CV 5/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 5/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.816 total time=   0.9s
# [CV 1/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 1/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.837 total time=   2.0s
# [CV 2/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 2/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.754 total time=   1.8s
# [CV 3/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 3/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.787 total time=   1.7s
# [CV 4/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 4/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.754 total time=   1.5s
# [CV 5/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 5/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.797 total time=   1.8s
# [CV 1/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 1/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.837 total time=   2.3s
# [CV 2/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 2/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.758 total time=   2.3s
# [CV 3/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 3/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.812 total time=   2.3s
# [CV 4/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 4/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.758 total time=   2.6s
# [CV 5/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 5/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.821 total time=   2.5s
# [CV 1/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 1/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.812 total time=   3.3s
# [CV 2/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 2/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.758 total time=   3.0s
# [CV 3/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 3/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.802 total time=   3.0s
# [CV 4/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 4/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.749 total time=   3.0s
# [CV 5/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 5/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.821 total time=   3.2s
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [3, 5, 8, 11],
#                          'n_estimators': [100, 200, 300, 400]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 30,
#  'max_features': 'log2',
#  'min_samples_split': 3,
#  'n_estimators': 400}

# %% [markdown]
# ### Final Model

# %%
Final_mod = ExtraTreesClassifier(criterion='gini',n_estimators= 200, max_depth=30 ,
                                 min_samples_split= 3, max_features= 'log2')
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.8378378378378378

# %%
from sklearn.metrics import RocCurveDisplay

disp = RocCurveDisplay.from_estimator(Final_mod,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.figure(figsize=(10,10))
plt.show()
from sklearn.metrics import roc_auc_score
auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.8379585456464809

# %% [markdown]
# ### Predicting the Final Model

# %%
# Prediction
prediction = Final_mod.predict(X_test)

# %%
Actual = np.array(Y_test)
df_Pred = pd.DataFrame()
df_Pred["Predicted Values"] = prediction
df_Pred["Actual Values"] = Actual
df_Pred.head()
# Out:
#    Predicted Values  Actual Values
# 0                 1              1
# 1                 0              0
# 2                 0              0
# 3                 1              1
# 4                 0              1
